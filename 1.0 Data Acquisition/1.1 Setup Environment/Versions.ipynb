# %%
# !git log --oneline
# Out:
# cb05de2 (HEAD -> master, origin/master, origin/HEAD) Simulate data set with 60 series. Try to fit OLS model and output CSV.
# 83f91c8 Two data generators dgf10, dgf11 and noise function.
# e6d3075 Simulated data examples
# ea901d6 Shorten the library loading snippet.
# 98a2bd4 Preparing simulate data series for clustering.
# fdcd4c4 hdbscan and tslearn is running. Docker image build version 1.0.1.
# ddcc75f Getting incompatible binary error. This might be the time to build a proper jupyter notebook for the thesis.
# 5bc1750 Load data generators and make dataset.
# e825661 Add function to generate dataset.
# af7fd0f Add nine data generator function. They produce simulate data series with monotonic characteristic.
# 7f77988 Setup R environment along side. We can run R if the machine has it installed.
# 8ddfb3d Setup so that password is blank. Just press enter to login.
# e1d7da8 Update docker image config. Run with /opt/workspace.
# 4776425 Add DTW
# 0550432 Add dist docker.
# 32e9c4f Compose file for distribution.
# 65bcf81 Last demo need to scale data with StandardScaler.
# 2fdef3d Set up portfolio selection experiment.
# 7124ccc Reorganize 2.0 folder. Dont want to have more than 10 subfolders here.
# 3399f8e KMeans with PCA for 160 stocks, checked with Silhouette and t-SNE.
# c846a88 Using v1.0 with pyplot.
# 4dbaeb0 Add technical indicator and fundamental data files.
# eadbe67 Fixed version for Jupyter Notebook container to 1.0
# d5b6a71 Move Write-Up folder to private repo. Updated Docker image to use latest JupyterLab.
# 62e244f Use V4 and _Read to build stock.db. Now working on feature selection in FourStock_ScatterplotMatrix notebook.
# e1b65b0 Dump PostgreSQL to SQLite3. 12 features.
# 07f7aab Build company dim, time dim, daily fact tables.
# 459830d Add industry/sector lookup to complete symbols universe.
# b382822 Merge branch 'master' of https://github.com/chayapan/thesis
# cab1e03 To add the sector and industry to stock_ticker.csv so can do lookup and map stock to market sector.
# 016c7d2 Markdown version of LaTex equations.
# 263fa11 Merge branch 'master' of https://github.com/chayapan/thesis
# 7bc4012 Test whether scaling affect PCA.
# 4977bab Merge branch 'master' of https://github.com/chayapan/thesis
# 1ca6054 Stock Grouping v1. BuildDataSetV4 and add feature V4.
# ebe1464 Add final data. Rewrite in-memory temp disk view to read from data home from OS environment.
# 1ae22b9 Get all required data from Datastream. Need to finish databsae.
# 94cd6ea Build dataset V3 populate DB table and provide two SQL views. 10 attributes are built.
# 93659f5 rename database file to stock.db. add MACD time-series data.
# 3a6d0dc Rearrange data files into structure.
# fbb387f Freeze eikon-data
# b4cb393 Freeze 1,3,write-up
# 23abb5c Freeze 2.0
# 04a7a50 Freeze 4.0 folder.
# 3e22d64 Freeze pilot.data and set100.data folders.
# 7b702f5 Two views for data access: Date and Stock. Feature engineering for volume, momentum, MACD, and value for stock grouping.
# 6498db8 Script for compiling data set and base procedure to run PCA.
# b458b44 Updated data templates.
# 2ef0c56 Merge branch 'master' of https://github.com/chayapan/thesis
# 5b2f8d8 SET100.xlsx on another computer.
# 9378751 Move stock list and YH update script under dataset/
# df57b50 Move tables/ and figures/ under Write-Up
# fe28d60 Excel template with attributes defined for fetching data from Datastream.
# 8eb0bd2 Add feature set 02 function
# a8838ac dataset FS02 with feature columns from ta. K-Means and PCA notebooks with tutorial using mtcars data set.
# 19dabb1 Scripts for compiling features to data series.
# 6c7f9a1 Dataset with features.
# 02d7c53 Confirm there is 129 stocks will suitable observation count.
# 3a50602 Test technical indicator calculations.
# 4a1ad26 Fixed dataset of 150 stocks.
# 0bc79ff Refresh data.
# c4acb4e Eikon dataset with 150 stocks.
# 1b48212 SET100 company between 2015-2019. There are 150 companies.
# d7db150 Correct symbols: MTLS->MTC.
# 9ac31fc Correct symbols: SEPPE->SAPPE, LHBANK->LHFG
# 52a32fd Use chayapan/thesis Jupyter container from thesis-d.git/thesis-notebook
# ff8a7d3 Merge branch 'master' of https://github.com/chayapan/thesis
# ceaf11c Set version of talib.
# 3d71ee6 Building SET100 data set.
# 5b34392 Forgot to use ExcelWriter.
# af06de1 Update list 2015-2019
# f4a3597 Merge branch 'master' of https://github.com/chayapan/thesis
# 5707e2c SET100 update data
# cf40c0d wrong database.
# 320fa96 SQLite3 database and ml_home shared library.
# 4a0f830 SET100 data during 2015-2019
# 22d3797 List of SET100 stocks during 2015-2019.
# 113609e Dataset for Pilot training.
# 9fff1bd Merge branch 'master' of https://github.com/chayapan/thesis
# 4ddfd85 RNN tutorial with LSTM 50-50-50-50 using 60 days history to predict 1-day ahead.
# 6f43c16 MACD and RegressionLineSlope features. Update script path settings.
# 98a8d7b work on PCA, RF feature importance, Correlation analysis. 3 time frame analysis.
# 3530c4c Working on feature selection via random forest fitting and variable imortance analysis.
# 5192fb0 Implementation of first 7 technical analysis indicator as time-series features.
# a792392 Fix conflict in lit review.
# fe202a2 Point to internal wiki. This should be remove.
# 9bcfb74 Reorganize 1.0. Bring processing script out of nested folder. The 1.x.x should only be used for write-up report generation or data analysis.
# f65e657 Create dataset/ folder to consolidate all data use in this thesis.
# 4312659 Tuck 1.X under 1.0 folder.
# b312eeb Start code template for 20 or so TI features.
# 7e9caa3 Colleced data for daily trading value by investor types and NVDR trading.
# d59f762 Coding of equation in markdown. This snippet was tested in Jupyter Notebook.
# 1fb7d26 Test markdown link.
# 279d089 Put markdown items for quick-access via the web.
# 0b8fe3c Ignore ARIMA output. Add figures folders. Add files about volatility and h-clustering to feature engineer. Correct sector/industry lookup code.
# fe4482b Fix parsing error. Now getting full result set.
# 32d78ed XGBoost model v1
# 47ed799 Put SVR models under SVR folder.
# 9509a6a Add Volatility computation notebook.
# d092cdf Create 1.0 folder and put 1.1 under it.
# b3457ac Add indices data. Add readme.
# 6c55aaf 1. Parallel processing stop working. 2. Review ARIMA window date. Need to write down exactly when prediction is made. What is the timeline. 3. Use Jupyter notebook to debug the metric collector.
# 77468c2 Using imap for multiprocessing.
# db731cc Try to improve parallel job.
# 985f9fd Analyze 36 stocks in SET50.
# 8943168 Catch exception for parallel job error. Save MSE. Run with more ARIMA order.
# 011db95 Running SET50 ARIMA error dist collection on ICT30.
# 89de366 add matplotlib
# 1e02dad To run on ICT30
# 1b0198c Merge pull request #5 from chayapan/dependabot/pip/tensorflow-2.3.1
# 184b407 Merge pull request #3 from chayapan/dependabot/pip/django-3.0.7
# bb99daf Batch run to collect error data for ARIMA.
# 3a1fd7b (origin/dependabot/pip/tensorflow-2.3.1) Bump tensorflow from 2.0.1 to 2.3.1
# 9db6b74 Set up universe process. From process table to CSV.
# bd7a681 Lookup table for Eikon dataset. Add TALib to VA series.
# c5d9aea Process Eikon data from excel files. Read and filter in Pandas.
# ddc8144 Analyze variance of daily returns of historical dataset.
# 30f5a75 2014-2020 Dataset
# 7ca7747 (origin/dependabot/pip/django-3.0.7) Bump django from 3.0 to 3.0.7
# 349e3a8 Driver program to train and save model
# df8c54c 2017 data, models, results
# 261b442 (tag: start-write-up) Chapter 1 for write-up and SVR results from last week.
# 4a401a3 SVR model looks ok. Add financial data. Add invariant check.
# e9455a8 Historical data store on github for easy retrieval
# a301d81 Stuck with no indices and risk-free source.
# f134ddb Update 1.2.1 List of stocks.ipynb
# 15cd70e Add fenced code block.
# 99d7969 Add code block to readme.
# e065bbf Update README.md
# 1fe89e9 Merge pull request #1 from chayapan/dependabot/pip/tensorflow-2.0.1
# 6e95497 Merge pull request #2 from chayapan/chayapan-patch-1
# ed76121 (origin/chayapan-patch-1) Create README.md
# b4723a1 Bump tensorflow from 2.0.0 to 2.0.1
# 9a388fb docker compose environemnt and python requirements.
# 247eca5 move over old scripts.
# b74d9f3 initial commit

# %%
from experiment import init_experiment
db_engine = init_experiment(EXPERIMENT_HOME)
# Out:
# Experiment Home:  /opt/workspace ; Data Home: /opt/workspace/dataset ;
# Database: Engine(postgresql://datauser:***@172.18.0.1:5432/stockdb)

# %%
import sys
sys.path
# Out:
# ['/opt/workspace',
#  '/opt/workspace',
#  '/opt/workspace/tests',
#  '/opt/workspace',
#  '/opt/workspace/ml_home',
#  '/opt/workspace/1.0 Data Acquisition/1.1 Setup Environment',
#  '/opt/conda/lib/python37.zip',
#  '/opt/conda/lib/python3.7',
#  '/opt/conda/lib/python3.7/lib-dynload',
#  '',
#  '/home/jovyan/.local/lib/python3.7/site-packages',
#  '/opt/conda/lib/python3.7/site-packages',
#  '/opt/conda/lib/python3.7/site-packages/IPython/extensions',
#  '/home/jovyan/.ipython']

# %%
pip list
# Out:
# Package                Version
# ---------------------- -------------------
# absl-py                0.11.0
# alembic                1.3.3
# alphalens              0.4.0
# anyio                  2.2.0
# asgiref                3.3.1
# astunparse             1.6.3
# async-generator        1.10
# attrs                  19.3.0
# Babel                  2.9.0
# backcall               0.1.0
# bcolz                  1.2.1
# beautifulsoup4         4.8.2
# bleach                 3.1.0
# blinker                1.4
# bokeh                  1.4.0
# Bottleneck             1.3.2
# cachetools             4.2.0
# certifi                2019.11.28
# certipy                0.1.3
# cffi                   1.13.2
# chardet                3.0.4
# Click                  7.0
# cloudpickle            1.2.2
# conda                  4.7.12
# conda-package-handling 1.6.0
# cryptography           2.8
# cvxpy                  1.0.25
# cycler                 0.10.0
# Cython                 0.29.14
# cytoolz                0.10.1
# dask                   2.9.2
# debacl                 1.1
# decorator              4.4.1
# defusedxml             0.6.0
# dill                   0.3.3
# distributed            2.10.0
# Django                 3.1.4
# django-crispy-forms    1.9.1
# django-debug-toolbar   2.2
# django-ide             0.0.5
# django-wysiwyg         0.8.0
# dtw-python             1.1.6
# ecos                   2.0.7.post1
# empyrical              0.5.5
# entrypoints            0.3
# fastcache              1.1.0
# fastcluster            1.1.28
# fastdtw                0.3.4
# flatbuffers            1.12
# fsspec                 0.6.2
# future                 0.18.2
# gast                   0.3.3
# gmpy2                  2.1.0b1
# google-auth            1.24.0
# google-auth-oauthlib   0.4.2
# google-pasta           0.2.0
# grpcio                 1.34.0
# h5py                   2.10.0
# hdbscan                0.8.27
# HeapDict               1.0.1
# html5lib               1.1
# idna                   2.8
# imageio                2.6.1
# importlib-metadata     1.5.0
# inflect                4.0.0
# iniconfig              1.1.1
# intervaltree           3.1.0
# ipykernel              5.1.4
# ipython                7.11.1
# ipython-genutils       0.2.0
# ipywidgets             7.5.1
# iso3166                1.0.1
# iso4217                1.6.20180829
# jaraco.itertools       5.0.0
# jedi                   0.16.0
# Jinja2                 2.11.0
# joblib                 1.0.1
# json5                  0.8.5
# jsonschema             3.2.0
# jupyter-client         6.1.11
# jupyter-core           4.6.1
# jupyter-packaging      0.7.12
# jupyter-server         1.4.1
# jupyter-telemetry      0.0.4
# jupyterhub             1.1.0
# jupyterlab             3.0.9
# jupyterlab-server      2.3.0
# Keras                  2.3.0
# Keras-Applications     1.0.8
# Keras-Preprocessing    1.1.2
# kiwisolver             1.1.0
# llvmlite               0.31.0
# locket                 0.2.0
# Logbook                1.5.3
# lru-dict               1.1.7
# lxml                   4.5.0
# Mako                   1.1.0
# Markdown               3.3.3
# MarkupSafe             1.1.1
# matplotlib             3.1.2
# mistune                0.8.4
# more-itertools         8.2.0
# mpmath                 1.1.0
# msgpack                0.6.2
# multipledispatch       0.6.0
# multiprocess           0.70.11.1
# nbclassic              0.2.6
# nbconvert              5.6.1
# nbformat               5.0.4
# networkx               1.11
# nose                   1.3.7
# notebook               6.0.3
# numba                  0.48.0
# numexpr                2.7.1
# numpy                  1.19.2
# oauthlib               3.0.1
# olefile                0.46
# opt-einsum             3.3.0
# osqp                   0.6.1
# packaging              20.1
# pamela                 1.0.0
# pandas                 0.25.3
# pandas-datareader      0.8.1
# pandocfilters          1.4.2
# parso                  0.6.0
# partd                  1.1.0
# patsy                  0.5.1
# pexpect                4.8.0
# pickleshare            0.7.5
# Pillow                 7.0.0
# pip                    20.0.2
# plotly                 4.14.3
# pluggy                 0.13.1
# prettytable            2.1.0
# prometheus-client      0.7.1
# prompt-toolkit         3.0.3
# protobuf               3.11.2
# psutil                 5.6.7
# psycopg2-binary        2.8.6
# ptyprocess             0.6.0
# py                     1.10.0
# py4j                   0.10.9
# pyasn1                 0.4.8
# pyasn1-modules         0.2.8
# pyclustering           0.10.1.2
# pycosat                0.6.3
# pycparser              2.19
# pycurl                 7.43.0.4
# pyfolio                0.9.2
# Pygments               2.5.2
# PyJWT                  1.7.1
# pyOpenSSL              19.1.0
# pyparsing              2.4.6
# pyrsistent             0.15.7
# PySocks                1.7.1
# pyspark                3.1.1
# pytest                 6.2.2
# python-dateutil        2.8.1
# python-editor          1.0.4
# python-interface       1.6.0
# python-json-logger     0.1.11
# python-redmine         2.3.0
# pytz                   2019.3
# PyWavelets             1.1.1
# PyYAML                 5.3
# pyzmq                  18.1.1
# regex                  2020.11.13
# requests               2.25.1
# requests-oauthlib      1.3.0
# retrying               1.3.3
# rsa                    4.6
# ruamel-yaml            0.15.80
# ruamel.yaml            0.16.6
# ruamel.yaml.clib       0.2.0
# scikit-image           0.16.2
# scikit-learn           0.24.0
# scipy                  1.4.1
# scs                    2.1.2
# seaborn                0.11.1
# Send2Trash             1.5.0
# setuptools             45.1.0.post20200119
# six                    1.15.0
# sniffio                1.2.0
# sortedcontainers       2.1.0
# soupsieve              1.9.4
# SQLAlchemy             1.3.20
# sqlparse               0.4.1
# statsmodels            0.12.1
# sympy                  1.5.1
# ta                     0.7.0
# tables                 3.6.1
# tabulate               0.8.7
# talib-binary           0.4.19
# tblib                  1.7.0
# tensorboard            2.4.0
# tensorboard-plugin-wit 1.7.0
# tensorflow             2.4.0
# tensorflow-estimator   2.4.0
# termcolor              1.1.0
# terminado              0.8.3
# testpath               0.4.4
# textile                4.0.1
# threadpoolctl          2.1.0
# toml                   0.10.2
# toolz                  0.10.0
# tornado                6.1
# tqdm                   4.42.0
# trading-calendars      2.1.1
# traitlets              4.3.3
# tslearn                0.5.0.5
# typing-extensions      3.7.4.3
# urllib3                1.25.7
# vincent                0.4.4
# wcwidth                0.1.8
# webencodings           0.5.1
# Werkzeug               1.0.1
# wheel                  0.36.2
# widgetsnbextension     3.5.1
# wrapt                  1.12.1
# xlrd                   1.2.0
# zict                   1.0.0
# zipline                1.4.1
# zipp                   2.1.0
# Note: you may need to restart the kernel to use updated packages.

# %%
get_ipython().profile_dir.startup_dir
# Out:
# '/home/jovyan/.ipython/profile_default/startup'
