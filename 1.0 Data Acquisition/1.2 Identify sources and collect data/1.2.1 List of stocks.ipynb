# %% [markdown]
# # 1.2.1 List of stocks
#
#
#
# ## Data source:
#
# ข้อมูลบริษัท/หลักทรัพย์ -> ตราสารทุน -> รายชื่อบริษัท / หลักทรัพย์
#
# https://www.set.or.th/th/company/companylist.html
#
# รายละเอียด รายชื่อบริษัทจดทะเบียนในตลาดหลักทรัพย์ (ปรับปรุงข้อมูลทุกวันทำการแรกของแต่ละสัปดาห์) https://www.set.or.th/dat/eod/listedcompany/static/listedCompanies_th_TH.xls
#
#
# English language
# https://www.set.or.th/dat/eod/listedcompany/static/listedCompanies_en_US.xls
#
#
# The Excel file **securities.xls** contains the list of all ticker symbols. It was downloaded from the Stock Exchange of Thailand website. The output of this process is CSV file **stock_ticker.csv**.
#
# ## Process
#
# 1. Download data from URL
# 2. Decode data from TIS-620
# 3. Parse HTML content to XML tree
# 4. Use xpath to extract each row and transform
# 5. Filter only SET
# 6. Show data to inspect data frame
# 7. Output saved to 'stock_ticker.csv'
#
#
# ### Required Python Modules
#
# ~~~
# requests
# pandas
# lxml
# ~~~

# %%
# Import required library

import pandas as pd
import requests
from lxml import etree

# %%
# Download data

# src = "https://www.set.or.th/dat/eod/listedcompany/static/listedCompanies_th_TH.xls"

src = "https://www.set.or.th/dat/eod/listedcompany/static/listedCompanies_en_US.xls"

r = requests.get(src)
content = r.content.decode('tis-620')

r.status_code, content[:300] # sample first 300 characters
# Out:
# (200,
#  '<table cellSpacing="0" cellPadding="0" width="100%" border="0">\n  <tr>\n    <td colspan="6" align="left"><strong>List of  Listed Companies & Contact Information</strong></td>\n    <td colspan="4" align="right"><strong>As of 30 Nov 2020<strong></td>\n  </tr>\n  <tr align="center" bgcolor="#C0C0C0"> \n    ')

# %%
# Decode and parse

html = etree.HTML(r.content.decode('tis-620'))

# %%
# Extract rows

stocks = {}

class Company:
    def __init__(self, row):
        self._row = row
        self.exchange = self._cell_data(2).strip().upper()
        self.symbol = self._cell_data(0).strip().upper()
        self.name = self._cell_data(1).strip()
        self.industry = self._cell_data(3).strip()
        self.sector = self._cell_data(4).strip()
        self.address = self._cell_data(5).strip()
        self.zipcode = self._cell_data(6).strip()
        self.telephone = self._cell_data(7).strip()
        self.fax = self._cell_data(8).strip()
        self.zipcode = self._cell_data(9).strip()
        self._row = row
    def _cell_data(self, column_number):
        row = self._row
        try:
            if row.getchildren()[column_number].text is None:
                return ""
            return row.getchildren()[column_number].text
        except:
            return ""
        
    def __str__(self):
        return """<Company %s:%s >""" % (self.exchange, self.symbol,)

for row in html.xpath('//tr'):
    print(row.getchildren()[0].text,len(row.getchildren()))
    if (len(row.getchildren()) >= 5) and (row.getchildren()[0].text is not None):
        try:
            company = Company(row)
            print(company)
            stocks[company.symbol] = company
        except Exception as e:
            print("Error for %s %s" % (str(e), row))
# Out:
# None 2
# None 10
# 2S                   10
# <Company MAI:2S >
# 3K-BAT               10
# <Company SET:3K-BAT >
# 7UP                  10
# <Company SET:7UP >
# A                    10
# <Company SET:A >
# A5                   10
# <Company MAI:A5 >
# AAV                  10
# <Company SET:AAV >
# ABICO                10
# <Company MAI:ABICO >
# ABM                  10
# <Company MAI:ABM >
# ABPIF                10
# <Company SET:ABPIF >
# ACAP                 10
# <Company MAI:ACAP >
# ACC                  10
# <Company SET:ACC >
# ACE                  10
# <Company SET:ACE >
# ACG                  10
# <Company SET:ACG >
# ADB                  10
# <Company MAI:ADB >
# ADVANC               10
# <Company SET:ADVANC >
# AEC                  10
# <Company SET:AEC >
# AEONTS               10
# <Company SET:AEONTS >
# AF                   10
# <Company MAI:AF >
# AFC                  10
# <Company SET:AFC >
# AGE                  10
# <Company SET:AGE >
# AH                   10
# <Company SET:AH >
# AHC                  10
# <Company SET:AHC >
# AI                   10
# <Company SET:AI >
# AIE                  10
# <Company MAI:AIE >
# AIMCG                10
# <Company SET:AIMCG >
# AIMIRT               10
# <Company SET:AIMIRT >
# AIRA                 10
# <Company MAI:AIRA >
# AIT                  10
# <Company SET:AIT >
# AJ                   10
# <Company SET:AJ >
# AJA                  10
# <Company SET:AJA >
# AKP                  10
# <Company MAI:AKP >
# AKR                  10
# <Company SET:AKR >
# ALL                  10
# <Company MAI:ALL >
# ALLA                 10
# <Company SET:ALLA >
# ALT                  10
# <Company SET:ALT >
# ALUCON               10
# <Company SET:ALUCON >
# AMA                  10
# <Company MAI:AMA >
# AMANAH               10
# <Company SET:AMANAH >
# AMARIN               10
# <Company SET:AMARIN >
# AMATA                10
# <Company SET:AMATA >
# AMATAR               10
# <Company SET:AMATAR >
# AMATAV               10
# <Company SET:AMATAV >
# AMC                  10
# <Company SET:AMC >
# ANAN                 10
# <Company SET:ANAN >
# AOT                  10
# <Company SET:AOT >
# AP                   10
# <Company SET:AP >
# APCO                 10
# <Company SET:APCO >
# APCS                 10
# <Company SET:APCS >
# APEX                 10
# <Company SET:APEX >
# APP                  10
# <Company MAI:APP >
# APURE                10
# <Company SET:APURE >
# AQ                   10
# <Company SET:AQ >
# AQUA                 10
# <Company SET:AQUA >
# ARIN                 10
# <Company MAI:ARIN >
# ARIP                 10
# <Company MAI:ARIP >
# ARROW                10
# <Company MAI:ARROW >
# AS                   10
# <Company SET:AS >
# ASAP                 10
# <Company SET:ASAP >
# ASEFA                10
# <Company SET:ASEFA >
# ASIA                 10
# <Company SET:ASIA >
# ASIAN                10
# <Company SET:ASIAN >
# ASIMAR               10
# <Company SET:ASIMAR >
# ASK                  10
# <Company SET:ASK >
# ASN                  10
# <Company MAI:ASN >
# ASP                  10
# <Company SET:ASP >
# ATP30                10
# <Company MAI:ATP30 >
# AU                   10
# <Company MAI:AU >
# AUCT                 10
# <Company MAI:AUCT >
# AWC                  10
# <Company SET:AWC >
# AYUD                 10
# <Company SET:AYUD >
# B                    10
# <Company SET:B >
# B52                  10
# <Company SET:B52 >
# BA                   10
# <Company SET:BA >
# BAFS                 10
# <Company SET:BAFS >
# BAM                  10
# <Company SET:BAM >
# BANPU                10
# <Company SET:BANPU >
# BAY                  10
# <Company SET:BAY >
# BBL                  10
# <Company SET:BBL >
# BC                   10
# <Company MAI:BC >
# BCH                  10
# <Company SET:BCH >
# BCP                  10
# <Company SET:BCP >
# BCPG                 10
# <Company SET:BCPG >
# BCT                  10
# <Company SET:BCT >
# BDMS                 10
# <Company SET:BDMS >
# BEAUTY               10
# <Company SET:BEAUTY >
# BEC                  10
# <Company SET:BEC >
# BEM                  10
# <Company SET:BEM >
# BFIT                 10
# <Company SET:BFIT >
# BGC                  10
# <Company SET:BGC >
# BGRIM                10
# <Company SET:BGRIM >
# BGT                  10
# <Company MAI:BGT >
# BH                   10
# <Company SET:BH >
# BIG                  10
# <Company SET:BIG >
# BIZ                  10
# <Company MAI:BIZ >
# BJC                  10
# <Company SET:BJC >
# BJCHI                10
# <Company SET:BJCHI >
# BKD                  10
# <Company SET:BKD >
# BKER                 10
# <Company SET:BKER >
# BKI                  10
# <Company SET:BKI >
# BKKCP                10
# <Company SET:BKKCP >
# BLA                  10
# <Company SET:BLA >
# BLAND                10
# <Company SET:BLAND >
# BLISS                10
# <Company SET:BLISS >
# BM                   10
# <Company MAI:BM >
# BOFFICE              10
# <Company SET:BOFFICE >
# BOL                  10
# <Company MAI:BOL >
# BPP                  10
# <Company SET:BPP >
# BR                   10
# <Company SET:BR >
# BROCK                10
# <Company SET:BROCK >
# BROOK                10
# <Company MAI:BROOK >
# BRR                  10
# <Company SET:BRR >
# BRRGIF               10
# <Company SET:BRRGIF >
# BSBM                 10
# <Company SET:BSBM >
# BSM                  10
# <Company MAI:BSM >
# BTNC                 10
# <Company SET:BTNC >
# BTS                  10
# <Company SET:BTS >
# BTSGIF               10
# <Company SET:BTSGIF >
# BTW                  10
# <Company MAI:BTW >
# BUI                  10
# <Company SET:BUI >
# BWG                  10
# <Company SET:BWG >
# B-WORK               10
# <Company SET:B-WORK >
# CAZ                  10
# <Company MAI:CAZ >
# CBG                  10
# <Company SET:CBG >
# CCET                 10
# <Company SET:CCET >
# CCP                  10
# <Company SET:CCP >
# CEN                  10
# <Company SET:CEN >
# CENTEL               10
# <Company SET:CENTEL >
# CFRESH               10
# <Company SET:CFRESH >
# CGD                  10
# <Company SET:CGD >
# CGH                  10
# <Company SET:CGH >
# CHARAN               10
# <Company SET:CHARAN >
# CHAYO                10
# <Company MAI:CHAYO >
# CHEWA                10
# <Company MAI:CHEWA >
# CHG                  10
# <Company SET:CHG >
# CHO                  10
# <Company MAI:CHO >
# CHOTI                10
# <Company SET:CHOTI >
# CHOW                 10
# <Company MAI:CHOW >
# CI                   10
# <Company SET:CI >
# CIG                  10
# <Company MAI:CIG >
# CIMBT                10
# <Company SET:CIMBT >
# CITY                 10
# <Company SET:CITY >
# CK                   10
# <Company SET:CK >
# CKP                  10
# <Company SET:CKP >
# CM                   10
# <Company SET:CM >
# CMAN                 10
# <Company SET:CMAN >
# CMC                  10
# <Company MAI:CMC >
# CMO                  10
# <Company MAI:CMO >
# CMR                  10
# <Company SET:CMR >
# CNT                  10
# <Company SET:CNT >
# COL                  10
# <Company SET:COL >
# COLOR                10
# <Company MAI:COLOR >
# COM7                 10
# <Company SET:COM7 >
# COMAN                10
# <Company MAI:COMAN >
# COTTO                10
# <Company SET:COTTO >
# CPALL                10
# <Company SET:CPALL >
# CPF                  10
# <Company SET:CPF >
# CPH                  10
# <Company SET:CPH >
# CPI                  10
# <Company SET:CPI >
# CPL                  10
# <Company SET:CPL >
# CPN                  10
# <Company SET:CPN >
# CPNCG                10
# <Company SET:CPNCG >
# CPNREIT              10
# <Company SET:CPNREIT >
# CPR                  10
# <Company MAI:CPR >
# CPT                  10
# <Company SET:CPT >
# CPTGF                10
# <Company SET:CPTGF >
# CPW                  10
# <Company SET:CPW >
# CRANE                10
# <Company SET:CRANE >
# CRC                  10
# <Company SET:CRC >
# CRD                  10
# <Company MAI:CRD >
# CSC                  10
# <Company SET:CSC >
# CSP                  10
# <Company SET:CSP >
# CSR                  10
# <Company SET:CSR >
# CSS                  10
# <Company SET:CSS >
# CTARAF               10
# <Company SET:CTARAF >
# CTW                  10
# <Company SET:CTW >
# CWT                  10
# <Company SET:CWT >
# D                    10
# <Company MAI:D >
# DCC                  10
# <Company SET:DCC >
# DCON                 10
# <Company SET:DCON >
# DDD                  10
# <Company SET:DDD >
# DELTA                10
# <Company SET:DELTA >
# DEMCO                10
# <Company SET:DEMCO >
# DHOUSE               10
# <Company MAI:DHOUSE >
# DIF                  10
# <Company SET:DIF >
# DIMET                10
# <Company MAI:DIMET >
# DOD                  10
# <Company MAI:DOD >
# DOHOME               10
# <Company SET:DOHOME >
# DREIT                10
# <Company SET:DREIT >
# DRT                  10
# <Company SET:DRT >
# DTAC                 10
# <Company SET:DTAC >
# DTC                  10
# <Company SET:DTC >
# DTCI                 10
# <Company SET:DTCI >
# DV8                  10
# <Company MAI:DV8 >
# EA                   10
# <Company SET:EA >
# EASON                10
# <Company SET:EASON >
# EASTW                10
# <Company SET:EASTW >
# ECF                  10
# <Company MAI:ECF >
# ECL                  10
# <Company SET:ECL >
# EE                   10
# <Company SET:EE >
# EFORL                10
# <Company MAI:EFORL >
# EGATIF               10
# <Company SET:EGATIF >
# EGCO                 10
# <Company SET:EGCO >
# EKH                  10
# <Company SET:EKH >
# EMC                  10
# <Company SET:EMC >
# EP                   10
# <Company SET:EP >
# EPG                  10
# <Company SET:EPG >
# ERW                  10
# <Company SET:ERW >
# ERWPF                10
# <Company SET:ERWPF >
# ESSO                 10
# <Company SET:ESSO >
# ESTAR                10
# <Company SET:ESTAR >
# ETC                  10
# <Company MAI:ETC >
# ETE                  10
# <Company MAI:ETE >
# EVER                 10
# <Company SET:EVER >
# F&D                  10
# <Company SET:F&D >
# FANCY                10
# <Company SET:FANCY >
# FE                   10
# <Company SET:FE >
# FLOYD                10
# <Company MAI:FLOYD >
# FMT                  10
# <Company SET:FMT >
# FN                   10
# <Company SET:FN >
# FNS                  10
# <Company SET:FNS >
# FORTH                10
# <Company SET:FORTH >
# FPI                  10
# <Company MAI:FPI >
# FPT                  10
# <Company SET:FPT >
# FSMART               10
# <Company MAI:FSMART >
# FSS                  10
# <Company SET:FSS >
# FTE                  10
# <Company SET:FTE >
# FTREIT               10
# <Company SET:FTREIT >
# FUTUREPF             10
# <Company SET:FUTUREPF >
# FVC                  10
# <Company MAI:FVC >
# GAHREIT              10
# <Company SET:GAHREIT >
# GBX                  10
# <Company SET:GBX >
# GC                   10
# <Company SET:GC >
# GCAP                 10
# <Company MAI:GCAP >
# GEL                  10
# <Company SET:GEL >
# GENCO                10
# <Company SET:GENCO >
# GFPT                 10
# <Company SET:GFPT >
# GGC                  10
# <Company SET:GGC >
# GIFT                 10
# <Company SET:GIFT >
# GJS                  10
# <Company SET:GJS >
# GL                   10
# <Company SET:GL >
# GLAND                10
# <Company SET:GLAND >
# GLOBAL               10
# <Company SET:GLOBAL >
# GLOCON               10
# <Company SET:GLOCON >
# GOLDPF               10
# <Company SET:GOLDPF >
# GPI                  10
# <Company SET:GPI >
# GPSC                 10
# <Company SET:GPSC >
# GRAMMY               10
# <Company SET:GRAMMY >
# GRAND                10
# <Company SET:GRAND >
# GREEN                10
# <Company SET:GREEN >
# GSC                  10
# <Company MAI:GSC >
# GSTEEL               10
# <Company SET:GSTEEL >
# GTB                  10
# <Company MAI:GTB >
# GULF                 10
# <Company SET:GULF >
# GUNKUL               10
# <Company SET:GUNKUL >
# GVREIT               10
# <Company SET:GVREIT >
# GYT                  10
# <Company SET:GYT >
# HANA                 10
# <Company SET:HANA >
# HARN                 10
# <Company MAI:HARN >
# HFT                  10
# <Company SET:HFT >
# HMPRO                10
# <Company SET:HMPRO >
# HPF                  10
# <Company SET:HPF >
# HPT                  10
# <Company MAI:HPT >
# HREIT                10
# <Company SET:HREIT >
# HTC                  10
# <Company SET:HTC >
# HTECH                10
# <Company SET:HTECH >
# HUMAN                10
# <Company SET:HUMAN >
# HYDRO                10
# <Company MAI:HYDRO >
# ICC                  10
# <Company SET:ICC >
# ICHI                 10
# <Company SET:ICHI >
# ICN                  10
# <Company MAI:ICN >
# IFEC                 10
# <Company SET:IFEC >
# IFS                  10
# <Company SET:IFS >
# IHL                  10
# <Company SET:IHL >
# IIG                  10
# <Company MAI:IIG >
# III                  10
# <Company SET:III >
# ILINK                10
# <Company SET:ILINK >
# ILM                  10
# <Company SET:ILM >
# IMH                  10
# <Company MAI:IMH >
# IMPACT               10
# <Company SET:IMPACT >
# INET                 10
# <Company SET:INET >
# INGRS                10
# <Company SET:INGRS >
# INOX                 10
# <Company SET:INOX >
# INSET                10
# <Company MAI:INSET >
# INSURE               10
# <Company SET:INSURE >
# INTUCH               10
# <Company SET:INTUCH >
# IP                   10
# <Company MAI:IP >
# IRC                  10
# <Company SET:IRC >
# IRCP                 10
# <Company MAI:IRCP >
# IRPC                 10
# <Company SET:IRPC >
# IT                   10
# <Company SET:IT >
# ITD                  10
# <Company SET:ITD >
# ITEL                 10
# <Company MAI:ITEL >
# IVL                  10
# <Company SET:IVL >
# J                    10
# <Company SET:J >
# JAS                  10
# <Company SET:JAS >
# JASIF                10
# <Company SET:JASIF >
# JCK                  10
# <Company SET:JCK >
# JCKH                 10
# <Company MAI:JCKH >
# JCT                  10
# <Company SET:JCT >
# JKN                  10
# <Company SET:JKN >
# JMART                10
# <Company SET:JMART >
# JMT                  10
# <Company SET:JMT >
# JR                   10
# <Company SET:JR >
# JSP                  10
# <Company MAI:JSP >
# JTS                  10
# <Company SET:JTS >
# JUBILE               10
# <Company MAI:JUBILE >
# JUTHA                10
# <Company SET:JUTHA >
# JWD                  10
# <Company SET:JWD >
# K                    10
# <Company MAI:K >
# KAMART               10
# <Company SET:KAMART >
# KASET                10
# <Company MAI:KASET >
# KBANK                10
# <Company SET:KBANK >
# KBS                  10
# <Company SET:KBS >
# KBSPIF               10
# <Company SET:KBSPIF >
# KC                   10
# <Company SET:KC >
# KCAR                 10
# <Company SET:KCAR >
# KCE                  10
# <Company SET:KCE >
# KCM                  10
# <Company MAI:KCM >
# KDH                  10
# <Company SET:KDH >
# KGI                  10
# <Company SET:KGI >
# KIAT                 10
# <Company MAI:KIAT >
# KK                   10
# <Company MAI:KK >
# KKC                  10
# <Company SET:KKC >
# KKP                  10
# <Company SET:KKP >
# KOOL                 10
# <Company MAI:KOOL >
# KPNPF                10
# <Company SET:KPNPF >
# KSL                  10
# <Company SET:KSL >
# KTB                  10
# <Company SET:KTB >
# KTC                  10
# <Company SET:KTC >
# KTIS                 10
# <Company SET:KTIS >
# KUMWEL               10
# <Company MAI:KUMWEL >
# KUN                  10
# <Company MAI:KUN >
# KWC                  10
# <Company SET:KWC >
# KWG                  10
# <Company SET:KWG >
# KWM                  10
# <Company MAI:KWM >
# KYE                  10
# <Company SET:KYE >
# L&E                  10
# <Company SET:L&E >
# LALIN                10
# <Company SET:LALIN >
# LANNA                10
# <Company SET:LANNA >
# LDC                  10
# <Company MAI:LDC >
# LEE                  10
# <Company SET:LEE >
# LEO                  10
# <Company MAI:LEO >
# LH                   10
# <Company SET:LH >
# LHFG                 10
# <Company SET:LHFG >
# LHHOTEL              10
# <Company SET:LHHOTEL >
# LHK                  10
# <Company SET:LHK >
# LHPF                 10
# <Company SET:LHPF >
# LHSC                 10
# <Company SET:LHSC >
# LIT                  10
# <Company MAI:LIT >
# LOXLEY               10
# <Company SET:LOXLEY >
# LPH                  10
# <Company SET:LPH >
# LPN                  10
# <Company SET:LPN >
# LRH                  10
# <Company SET:LRH >
# LST                  10
# <Company SET:LST >
# LUXF                 10
# <Company SET:LUXF >
# M                    10
# <Company SET:M >
# MACO                 10
# <Company SET:MACO >
# MAJOR                10
# <Company SET:MAJOR >
# MAKRO                10
# <Company SET:MAKRO >
# MALEE                10
# <Company SET:MALEE >
# MANRIN               10
# <Company SET:MANRIN >
# MATCH                10
# <Company SET:MATCH >
# MATI                 10
# <Company SET:MATI >
# MAX                  10
# <Company SET:MAX >
# MBAX                 10
# <Company MAI:MBAX >
# MBK                  10
# <Company SET:MBK >
# MBKET                10
# <Company SET:MBKET >
# MC                   10
# <Company SET:MC >
# M-CHAI               10
# <Company SET:M-CHAI >
# MCOT                 10
# <Company SET:MCOT >
# MCS                  10
# <Company SET:MCS >
# MDX                  10
# <Company SET:MDX >
# MEGA                 10
# <Company SET:MEGA >
# META                 10
# <Company MAI:META >
# METCO                10
# <Company SET:METCO >
# MFC                  10
# <Company SET:MFC >
# MFEC                 10
# <Company SET:MFEC >
# MGT                  10
# <Company MAI:MGT >
# MICRO                10
# <Company SET:MICRO >
# MIDA                 10
# <Company SET:MIDA >
# M-II                 10
# <Company SET:M-II >
# MILL                 10
# <Company SET:MILL >
# MINT                 10
# <Company SET:MINT >
# MIPF                 10
# <Company SET:MIPF >
# MIT                  10
# <Company SET:MIT >
# MITSIB               10
# <Company MAI:MITSIB >
# MJD                  10
# <Company SET:MJD >
# MJLF                 10
# <Company SET:MJLF >
# MK                   10
# <Company SET:MK >
# ML                   10
# <Company SET:ML >
# MM                   10
# <Company MAI:MM >
# MNIT                 10
# <Company SET:MNIT >
# MNIT2                10
# <Company SET:MNIT2 >
# MNRF                 10
# <Company SET:MNRF >
# MODERN               10
# <Company SET:MODERN >
# MONO                 10
# <Company SET:MONO >
# MOONG                10
# <Company MAI:MOONG >
# MORE                 10
# <Company MAI:MORE >
# M-PAT                10
# <Company SET:M-PAT >
# MPG                  10
# <Company MAI:MPG >
# MPIC                 10
# <Company SET:MPIC >
# MSC                  10
# <Company SET:MSC >
# M-STOR               10
# <Company SET:M-STOR >
# MTC                  10
# <Company SET:MTC >
# MTI                  10
# <Company SET:MTI >
# MVP                  10
# <Company MAI:MVP >
# NBC                  10
# <Company MAI:NBC >
# NC                   10
# <Company SET:NC >
# NCAP                 10
# <Company SET:NCAP >
# NCH                  10
# <Company SET:NCH >
# NCL                  10
# <Company MAI:NCL >
# NDR                  10
# <Company MAI:NDR >
# NEP                  10
# <Company SET:NEP >
# NER                  10
# <Company SET:NER >
# NETBAY               10
# <Company MAI:NETBAY >
# NEW                  10
# <Company SET:NEW >
# NEWS                 10
# <Company MAI:NEWS >
# NEX                  10
# <Company SET:NEX >
# NFC                  10
# <Company SET:NFC >
# NINE                 10
# <Company MAI:NINE >
# NKI                  10
# <Company SET:NKI >
# NMG                  10
# <Company SET:NMG >
# NNCL                 10
# <Company SET:NNCL >
# NOBLE                10
# <Company SET:NOBLE >
# NOK                  10
# <Company SET:NOK >
# NPK                  10
# <Company MAI:NPK >
# NRF                  10
# <Company SET:NRF >
# NSI                  10
# <Company SET:NSI >
# NTV                  10
# <Company SET:NTV >
# NUSA                 10
# <Company SET:NUSA >
# NVD                  10
# <Company SET:NVD >
# NWR                  10
# <Company SET:NWR >
# NYT                  10
# <Company SET:NYT >
# OCC                  10
# <Company SET:OCC >
# OCEAN                10
# <Company MAI:OCEAN >
# OGC                  10
# <Company SET:OGC >
# OHTL                 10
# <Company SET:OHTL >
# OISHI                10
# <Company SET:OISHI >
# ORI                  10
# <Company SET:ORI >
# OSP                  10
# <Company SET:OSP >
# OTO                  10
# <Company MAI:OTO >
# PACE                 10
# <Company SET:PACE >
# PAE                  10
# <Company SET:PAE >
# PAF                  10
# <Company SET:PAF >
# PAP                  10
# <Company SET:PAP >
# PATO                 10
# <Company SET:PATO >
# PB                   10
# <Company SET:PB >
# PCSGH                10
# <Company SET:PCSGH >
# PDG                  10
# <Company MAI:PDG >
# PDI                  10
# <Company SET:PDI >
# PDJ                  10
# <Company SET:PDJ >
# PE                   10
# <Company SET:PE >
# PERM                 10
# <Company SET:PERM >
# PF                   10
# <Company SET:PF >
# PG                   10
# <Company SET:PG >
# PHOL                 10
# <Company MAI:PHOL >
# PICO                 10
# <Company MAI:PICO >
# PIMO                 10
# <Company MAI:PIMO >
# PJW                  10
# <Company MAI:PJW >
# PK                   10
# <Company SET:PK >
# PL                   10
# <Company SET:PL >
# PLANB                10
# <Company SET:PLANB >
# PLANET               10
# <Company MAI:PLANET >
# PLAT                 10
# <Company SET:PLAT >
# PLE                  10
# <Company SET:PLE >
# PM                   10
# <Company SET:PM >
# PMTA                 10
# <Company SET:PMTA >
# POLAR                10
# <Company SET:POLAR >
# POMPUI               10
# <Company SET:POMPUI >
# POPF                 10
# <Company SET:POPF >
# PORT                 10
# <Company SET:PORT >
# POST                 10
# <Company SET:POST >
# PPF                  10
# <Company SET:PPF >
# PPM                  10
# <Company MAI:PPM >
# PPP                  10
# <Company SET:PPP >
# PPPM                 10
# <Company SET:PPPM >
# PPS                  10
# <Company MAI:PPS >
# PR9                  10
# <Company SET:PR9 >
# PRAKIT               10
# <Company SET:PRAKIT >
# PRAPAT               10
# <Company MAI:PRAPAT >
# PREB                 10
# <Company SET:PREB >
# PRECHA               10
# <Company SET:PRECHA >
# PRG                  10
# <Company SET:PRG >
# PRIME                10
# <Company SET:PRIME >
# PRIN                 10
# <Company SET:PRIN >
# PRINC                10
# <Company SET:PRINC >
# PRM                  10
# <Company SET:PRM >
# PRO                  10
# <Company SET:PRO >
# PROSPECT             10
# <Company SET:PROSPECT >
# PROUD                10
# <Company MAI:PROUD >
# PSH                  10
# <Company SET:PSH >
# PSL                  10
# <Company SET:PSL >
# PSTC                 10
# <Company MAI:PSTC >
# PT                   10
# <Company SET:PT >
# PTG                  10
# <Company SET:PTG >
# PTL                  10
# <Company SET:PTL >
# PTT                  10
# <Company SET:PTT >
# PTTEP                10
# <Company SET:PTTEP >
# PTTGC                10
# <Company SET:PTTGC >
# PYLON                10
# <Company SET:PYLON >
# Q-CON                10
# <Company SET:Q-CON >
# QH                   10
# <Company SET:QH >
# QHHR                 10
# <Company SET:QHHR >
# QHOP                 10
# <Company SET:QHOP >
# QHPF                 10
# <Company SET:QHPF >
# QLT                  10
# <Company MAI:QLT >
# QTC                  10
# <Company MAI:QTC >
# RAM                  10
# <Company SET:RAM >
# RATCH                10
# <Company SET:RATCH >
# RBF                  10
# <Company SET:RBF >
# RCI                  10
# <Company SET:RCI >
# RCL                  10
# <Company SET:RCL >
# RICHY                10
# <Company SET:RICHY >
# RJH                  10
# <Company SET:RJH >
# RML                  10
# <Company SET:RML >
# ROCK                 10
# <Company SET:ROCK >
# ROH                  10
# <Company SET:ROH >
# ROJNA                10
# <Company SET:ROJNA >
# RP                   10
# <Company MAI:RP >
# RPC                  10
# <Company SET:RPC >
# RPH                  10
# <Company SET:RPH >
# RS                   10
# <Company SET:RS >
# RSP                  10
# <Company SET:RSP >
# RT                   10
# <Company SET:RT >
# RWI                  10
# <Company MAI:RWI >
# S                    10
# <Company SET:S >
# S & J                10
# <Company SET:S & J >
# S11                  10
# <Company SET:S11 >
# SAAM                 10
# <Company MAI:SAAM >
# SABINA               10
# <Company SET:SABINA >
# SABUY                10
# <Company MAI:SABUY >
# SAFARI               10
# <Company SET:SAFARI >
# SALEE                10
# <Company MAI:SALEE >
# SAM                  10
# <Company SET:SAM >
# SAMART               10
# <Company SET:SAMART >
# SAMCO                10
# <Company SET:SAMCO >
# SAMTEL               10
# <Company SET:SAMTEL >
# SANKO                10
# <Company MAI:SANKO >
# SAPPE                10
# <Company SET:SAPPE >
# SAT                  10
# <Company SET:SAT >
# SAUCE                10
# <Company SET:SAUCE >
# SAWAD                10
# <Company SET:SAWAD >
# SAWANG               10
# <Company SET:SAWANG >
# SBPF                 10
# <Company SET:SBPF >
# SC                   10
# <Company SET:SC >
# SCB                  10
# <Company SET:SCB >
# SCC                  10
# <Company SET:SCC >
# SCCC                 10
# <Company SET:SCCC >
# SCG                  10
# <Company SET:SCG >
# SCGP                 10
# <Company SET:SCGP >
# SCI                  10
# <Company SET:SCI >
# SCM                  10
# <Company SET:SCM >
# SCN                  10
# <Company SET:SCN >
# SCP                  10
# <Company SET:SCP >
# SDC                  10
# <Company SET:SDC >
# SE                   10
# <Company MAI:SE >
# SEAFCO               10
# <Company SET:SEAFCO >
# SEAOIL               10
# <Company MAI:SEAOIL >
# SE-ED                10
# <Company SET:SE-ED >
# SEG                  10
# <Company SET:SEG >
# SELIC                10
# <Company MAI:SELIC >
# SENA                 10
# <Company SET:SENA >
# SF                   10
# <Company SET:SF >
# SFLEX                10
# <Company SET:SFLEX >
# SFP                  10
# <Company SET:SFP >
# SFT                  10
# <Company MAI:SFT >
# SGF                  10
# <Company MAI:SGF >
# SGP                  10
# <Company SET:SGP >
# SHANG                10
# <Company SET:SHANG >
# SHR                  10
# <Company SET:SHR >
# SHREIT               10
# <Company SET:SHREIT >
# SIAM                 10
# <Company SET:SIAM >
# SICT                 10
# <Company MAI:SICT >
# SIMAT                10
# <Company MAI:SIMAT >
# SINGER               10
# <Company SET:SINGER >
# SIRI                 10
# <Company SET:SIRI >
# SIRIP                10
# <Company SET:SIRIP >
# SIS                  10
# <Company SET:SIS >
# SISB                 10
# <Company SET:SISB >
# SITHAI               10
# <Company SET:SITHAI >
# SK                   10
# <Company MAI:SK >
# SKE                  10
# <Company SET:SKE >
# SKN                  10
# <Company SET:SKN >
# SKR                  10
# <Company SET:SKR >
# SKY                  10
# <Company MAI:SKY >
# SLM                  10
# <Company MAI:SLM >
# SLP                  10
# <Company SET:SLP >
# SMART                10
# <Company MAI:SMART >
# SMIT                 10
# <Company SET:SMIT >
# SMK                  10
# <Company SET:SMK >
# SMPC                 10
# <Company SET:SMPC >
# SMT                  10
# <Company SET:SMT >
# SNC                  10
# <Company SET:SNC >
# SNP                  10
# <Company SET:SNP >
# SO                   10
# <Company SET:SO >
# SOLAR                10
# <Company SET:SOLAR >
# SONIC                10
# <Company MAI:SONIC >
# SORKON               10
# <Company SET:SORKON >
# SPA                  10
# <Company MAI:SPA >
# SPACK                10
# <Company SET:SPACK >
# SPALI                10
# <Company SET:SPALI >
# SPC                  10
# <Company SET:SPC >
# SPCG                 10
# <Company SET:SPCG >
# SPF                  10
# <Company SET:SPF >
# SPG                  10
# <Company SET:SPG >
# SPI                  10
# <Company SET:SPI >
# SPRC                 10
# <Company SET:SPRC >
# SPRIME               10
# <Company SET:SPRIME >
# SPVI                 10
# <Company MAI:SPVI >
# SQ                   10
# <Company SET:SQ >
# SR                   10
# <Company MAI:SR >
# SRICHA               10
# <Company SET:SRICHA >
# SRIPANWA             10
# <Company SET:SRIPANWA >
# SSC                  10
# <Company SET:SSC >
# SSF                  10
# <Company SET:SSF >
# SSP                  10
# <Company SET:SSP >
# SSPF                 10
# <Company SET:SSPF >
# SSSC                 10
# <Company SET:SSSC >
# SST                  10
# <Company SET:SST >
# SSTRT                10
# <Company SET:SSTRT >
# STA                  10
# <Company SET:STA >
# STANLY               10
# <Company SET:STANLY >
# STAR                 10
# <Company MAI:STAR >
# STARK                10
# <Company SET:STARK >
# STC                  10
# <Company MAI:STC >
# STEC                 10
# <Company SET:STEC >
# STGT                 10
# <Company SET:STGT >
# STHAI                10
# <Company SET:STHAI >
# STI                  10
# <Company MAI:STI >
# STPI                 10
# <Company SET:STPI >
# SUC                  10
# <Company SET:SUC >
# SUN                  10
# <Company MAI:SUN >
# SUPER                10
# <Company SET:SUPER >
# SUPEREIF             10
# <Company SET:SUPEREIF >
# SUSCO                10
# <Company SET:SUSCO >
# SUTHA                10
# <Company SET:SUTHA >
# SVH                  10
# <Company SET:SVH >
# SVI                  10
# <Company SET:SVI >
# SVOA                 10
# <Company SET:SVOA >
# SWC                  10
# <Company MAI:SWC >
# SYMC                 10
# <Company SET:SYMC >
# SYNEX                10
# <Company SET:SYNEX >
# SYNTEC               10
# <Company SET:SYNTEC >
# T                    10
# <Company MAI:T >
# TACC                 10
# <Company MAI:TACC >
# TAE                  10
# <Company SET:TAE >
# TAKUNI               10
# <Company MAI:TAKUNI >
# TAPAC                10
# <Company MAI:TAPAC >
# TASCO                10
# <Company SET:TASCO >
# TBSP                 10
# <Company SET:TBSP >
# TC                   10
# <Company SET:TC >
# TCAP                 10
# <Company SET:TCAP >
# TCC                  10
# <Company SET:TCC >
# TCCC                 10
# <Company SET:TCCC >
# TCJ                  10
# <Company SET:TCJ >
# TCMC                 10
# <Company SET:TCMC >
# TCOAT                10
# <Company SET:TCOAT >
# TEAM                 10
# <Company SET:TEAM >
# TEAMG                10
# <Company SET:TEAMG >
# TFFIF                10
# <Company SET:TFFIF >
# TFG                  10
# <Company SET:TFG >
# TFI                  10
# <Company SET:TFI >
# TFMAMA               10
# <Company SET:TFMAMA >
# TGPRO                10
# <Company SET:TGPRO >
# TH                   10
# <Company SET:TH >
# THAI                 10
# <Company SET:THAI >
# THANA                10
# <Company MAI:THANA >
# THANI                10
# <Company SET:THANI >
# THCOM                10
# <Company SET:THCOM >
# THE                  10
# <Company SET:THE >
# THG                  10
# <Company SET:THG >
# THIP                 10
# <Company SET:THIP >
# THL                  10
# <Company SET:THL >
# THMUI                10
# <Company MAI:THMUI >
# THRE                 10
# <Company SET:THRE >
# THREL                10
# <Company SET:THREL >
# TIF1                 10
# <Company SET:TIF1 >
# TIGER                10
# <Company MAI:TIGER >
# TIP                  10
# <Company SET:TIP >
# TIPCO                10
# <Company SET:TIPCO >
# TISCO                10
# <Company SET:TISCO >
# TITLE                10
# <Company MAI:TITLE >
# TIW                  10
# <Company SET:TIW >
# TK                   10
# <Company SET:TK >
# TKN                  10
# <Company SET:TKN >
# TKS                  10
# <Company SET:TKS >
# TKT                  10
# <Company SET:TKT >
# TLGF                 10
# <Company SET:TLGF >
# TLHPF                10
# <Company SET:TLHPF >
# TM                   10
# <Company MAI:TM >
# TMB                  10
# <Company SET:TMB >
# TMC                  10
# <Company MAI:TMC >
# TMD                  10
# <Company SET:TMD >
# TMI                  10
# <Company MAI:TMI >
# TMILL                10
# <Company MAI:TMILL >
# TMT                  10
# <Company SET:TMT >
# TMW                  10
# <Company MAI:TMW >
# TNDT                 10
# <Company MAI:TNDT >
# TNH                  10
# <Company MAI:TNH >
# TNITY                10
# <Company SET:TNITY >
# TNL                  10
# <Company SET:TNL >
# TNP                  10
# <Company MAI:TNP >
# TNPC                 10
# <Company SET:TNPC >
# TNPF                 10
# <Company SET:TNPF >
# TNR                  10
# <Company SET:TNR >
# TOA                  10
# <Company SET:TOA >
# TOG                  10
# <Company SET:TOG >
# TOP                  10
# <Company SET:TOP >
# TOPP                 10
# <Company SET:TOPP >
# TPA                  10
# <Company SET:TPA >
# TPAC                 10
# <Company MAI:TPAC >
# TPBI                 10
# <Company SET:TPBI >
# TPCH                 10
# <Company MAI:TPCH >
# TPCORP               10
# <Company SET:TPCORP >
# TPIPL                10
# <Company SET:TPIPL >
# TPIPP                10
# <Company SET:TPIPP >
# TPLAS                10
# <Company MAI:TPLAS >
# TPOLY                10
# <Company SET:TPOLY >
# TPP                  10
# <Company SET:TPP >
# TPRIME               10
# <Company SET:TPRIME >
# TPS                  10
# <Company MAI:TPS >
# TQM                  10
# <Company SET:TQM >
# TR                   10
# <Company SET:TR >
# TRC                  10
# <Company SET:TRC >
# TRITN                10
# <Company SET:TRITN >
# TRT                  10
# <Company MAI:TRT >
# TRU                  10
# <Company SET:TRU >
# TRUBB                10
# <Company SET:TRUBB >
# TRUE                 10
# <Company SET:TRUE >
# TSC                  10
# <Company SET:TSC >
# TSE                  10
# <Company SET:TSE >
# TSF                  10
# <Company MAI:TSF >
# TSI                  10
# <Company SET:TSI >
# TSR                  10
# <Company SET:TSR >
# TSTE                 10
# <Company SET:TSTE >
# TSTH                 10
# <Company SET:TSTH >
# TTA                  10
# <Company SET:TTA >
# TTCL                 10
# <Company SET:TTCL >
# TTI                  10
# <Company SET:TTI >
# TTLPF                10
# <Company SET:TTLPF >
# TTT                  10
# <Company SET:TTT >
# TTW                  10
# <Company SET:TTW >
# TU                   10
# <Company SET:TU >
# TU-PF                10
# <Company SET:TU-PF >
# TVD                  10
# <Company MAI:TVD >
# TVI                  10
# <Company SET:TVI >
# TVO                  10
# <Company SET:TVO >
# TVT                  10
# <Company MAI:TVT >
# TWP                  10
# <Company SET:TWP >
# TWPC                 10
# <Company SET:TWPC >
# TWZ                  10
# <Company SET:TWZ >
# TYCN                 10
# <Company SET:TYCN >
# U                    10
# <Company SET:U >
# UAC                  10
# <Company SET:UAC >
# UBIS                 10
# <Company MAI:UBIS >
# UEC                  10
# <Company MAI:UEC >
# UKEM                 10
# <Company MAI:UKEM >
# UMI                  10
# <Company SET:UMI >
# UMS                  10
# <Company MAI:UMS >
# UNIQ                 10
# <Company SET:UNIQ >
# UOBKH                10
# <Company SET:UOBKH >
# UP                   10
# <Company SET:UP >
# UPA                  10
# <Company MAI:UPA >
# UPF                  10
# <Company SET:UPF >
# UPOIC                10
# <Company SET:UPOIC >
# URBNPF               10
# <Company SET:URBNPF >
# UREKA                10
# <Company MAI:UREKA >
# UT                   10
# <Company SET:UT >
# UTP                  10
# <Company SET:UTP >
# UV                   10
# <Company SET:UV >
# UVAN                 10
# <Company SET:UVAN >
# UWC                  10
# <Company MAI:UWC >
# VARO                 10
# <Company SET:VARO >
# VCOM                 10
# <Company MAI:VCOM >
# VGI                  10
# <Company SET:VGI >
# VI                   10
# <Company SET:VI >
# VIBHA                10
# <Company SET:VIBHA >
# VIH                  10
# <Company SET:VIH >
# VL                   10
# <Company MAI:VL >
# VNG                  10
# <Company SET:VNG >
# VNT                  10
# <Company SET:VNT >
# VPO                  10
# <Company SET:VPO >
# VRANDA               10
# <Company SET:VRANDA >
# W                    10
# <Company SET:W >
# WACOAL               10
# <Company SET:WACOAL >
# WAVE                 10
# <Company SET:WAVE >
# WGE                  10
# <Company SET:WGE >
# WHA                  10
# <Company SET:WHA >
# WHABT                10
# <Company SET:WHABT >
# WHART                10
# <Company SET:WHART >
# WHAUP                10
# <Company SET:WHAUP >
# WICE                 10
# <Company SET:WICE >
# WIIK                 10
# <Company SET:WIIK >
# WIN                  10
# <Company SET:WIN >
# WINNER               10
# <Company MAI:WINNER >
# WORK                 10
# <Company SET:WORK >
# WORLD                10
# <Company SET:WORLD >
# WP                   10
# <Company SET:WP >
# WPH                  10
# <Company SET:WPH >
# WR                   10
# <Company SET:WR >
# XO                   10
# <Company MAI:XO >
# YCI                  10
# <Company SET:YCI >
# YGG                  10
# <Company MAI:YGG >
# YUASA                10
# <Company MAI:YUASA >
# ZEN                  10
# <Company SET:ZEN >
# ZIGA                 10
# <Company MAI:ZIGA >
# ZMICO                10
# <Company SET:ZMICO >

# %%
"Total tickers", len(stocks)
# Out:
# ('Total tickers', 807)

# %%
all_stocks = {}
for symbol, company in stocks.items():
  all_stocks[symbol] = {
        'symbol': company.symbol,
        'exchange': company.exchange,
        'industry': company.industry,
        'sector': company.sector,
        'name': company.name
  }

# %%
all_symbols = pd.DataFrame(all_stocks)
stocks = all_symbols.T
stocks
# SET_stocks = stocks[stocks['exchange']=='SET']


SET_stocks = stocks
SET_stocks
# Out:
#         symbol exchange                 industry                sector  \
# 2S          2S      MAI               Industrial                     -
# 3K-BAT  3K-BAT      SET              Industrials            Automotive
# 7UP        7UP      SET                Resources    Energy & Utilities
# A            A      SET  Property & Construction  Property Development
# A5          A5      MAI                 Services                     -
# ...        ...      ...                      ...                   ...
# YGG        YGG      MAI                 Services                     -
# YUASA    YUASA      MAI               Industrial                     -
# ZEN        ZEN      SET     Agro & Food Industry       Food & Beverage
# ZIGA      ZIGA      MAI               Industrial                     -
# ZMICO    ZMICO      SET               Financials  Finance & Securities
#
#                                                      name
# 2S                        2S METAL PUBLIC COMPANY LIMITED
# 3K-BAT  THAI ENERGY STORAGE TECHNOLOGY PUBLIC COMPANY ...
# 7UP      SEVEN UTILITIES AND POWER PUBLIC COMPANY LIMITED
# A                  AREEYA PROPERTY PUBLIC COMPANY LIMITED
# A5                ASSET FIVE GROUP PUBLIC COMPANY LIMITED
# ...                                                   ...
# YGG                YGGDRAZIL GROUP PUBLIC COMPANY LIMITED
# YUASA     YUASA BATTERY (THAILAND) PUBLIC COMPANY LIMITED
# ZEN          ZEN CORPORATION GROUP PUBLIC COMPANY LIMITED
# ZIGA               ZIGA INNOVATION PUBLIC COMPANY LIMITED
# ZMICO           SEAMICO SECURITIES PUBLIC COMPANY LIMITED
#
# [807 rows x 5 columns]

# %%
# Check lookup specific stock symbol.

stocks.loc[stocks['symbol']=='BAT3K']
# Out:
# Empty DataFrame
# Columns: [symbol, exchange, industry, sector, name]
# Index: []

# %%
output_file = "stock_ticker.csv"

SET_stocks.to_csv(output_file)


SET_stocks
# Out:
#         symbol exchange                 industry                sector  \
# 2S          2S      MAI               Industrial                     -
# 3K-BAT  3K-BAT      SET              Industrials            Automotive
# 7UP        7UP      SET                Resources    Energy & Utilities
# A            A      SET  Property & Construction  Property Development
# A5          A5      MAI                 Services                     -
# ...        ...      ...                      ...                   ...
# YGG        YGG      MAI                 Services                     -
# YUASA    YUASA      MAI               Industrial                     -
# ZEN        ZEN      SET     Agro & Food Industry       Food & Beverage
# ZIGA      ZIGA      MAI               Industrial                     -
# ZMICO    ZMICO      SET               Financials  Finance & Securities
#
#                                                      name
# 2S                        2S METAL PUBLIC COMPANY LIMITED
# 3K-BAT  THAI ENERGY STORAGE TECHNOLOGY PUBLIC COMPANY ...
# 7UP      SEVEN UTILITIES AND POWER PUBLIC COMPANY LIMITED
# A                  AREEYA PROPERTY PUBLIC COMPANY LIMITED
# A5                ASSET FIVE GROUP PUBLIC COMPANY LIMITED
# ...                                                   ...
# YGG                YGGDRAZIL GROUP PUBLIC COMPANY LIMITED
# YUASA     YUASA BATTERY (THAILAND) PUBLIC COMPANY LIMITED
# ZEN          ZEN CORPORATION GROUP PUBLIC COMPANY LIMITED
# ZIGA               ZIGA INNOVATION PUBLIC COMPANY LIMITED
# ZMICO           SEAMICO SECURITIES PUBLIC COMPANY LIMITED
#
# [807 rows x 5 columns]

# %% [markdown]
# # SET50 and SET100 sample for pilot
#
#
# SET 50  https://www.settrade.com/C13_MarketSummary.jsp?detail=SET50
#
# SET 100 https://www.settrade.com/C13_MarketSummary.jsp?detail=SET100

# %%
import lxml, requests
from lxml import html

src = "https://www.settrade.com/C13_MarketSummary.jsp?detail=SET50"
r = requests.get(src)
content = r.content.decode('tis-620')

_html = html.fromstring(content)
# _html.xpath("""//*[@id="maincontent"]/div/div[1]/div[1]/div/div[2]/div[3]/div/div/div/div/table/tbody/tr[15]/td[1]/a""")
links = _html.xpath("""//a[contains(@class,"link-stt") and contains(@href,'C13')]""") # link for each symbols

# %%
# links[0].getparent().getparent().tag  # 'tr'

symbols = []
for link in links:
    symbol = link.getparent().text_content().strip()
    symbols.append(symbol)

# %%
symbols

# %%
stocks = ['ADVANC',
 'AOT',
 'AWC',
 'BANPU',
 'BBL',
 'BDMS',
 'BEM',
 'BGRIM',
 'BH',]

# %%
stocks

# %%
import pandas_datareader as pdr
import datetime as dt


stocks = ['ADVANC', 'AOT', 'AWC', 'BANPU', 'BBL', 'BDMS', 'BEM', 'BGRIM', 'BH']
start = dt.datetime(2014,1,1)

dataset = {}
for s in stocks:
    try:
        data = pdr.get_data_yahoo('%s.BK' % s,start=start)
        dataset[s] = data
    except Exception as e:
        print("Error: %s %s" % (s, str(e)))

# %%
dataset
