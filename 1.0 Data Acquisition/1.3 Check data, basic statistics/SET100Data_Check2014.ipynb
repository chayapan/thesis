# %% [markdown]
# SET100 Data: Feature Set 01
#
# See Check2015-2019 for how to obtain the 129 stocks with complete observations.

# %%
import sys, os, os.path
if not 'EXPERIMENT_HOME' in os.environ: # Configure local paths if not already defined
    ML_HOME = os.path.abspath(os.path.join("/home/jovyan", "ml_home")) # ML workspace
    EXPERIMENT_HOME = os.path.abspath(os.path.join(ML_HOME, "..")) # Experiment workspace
    DATA_HOME = os.path.abspath(os.path.join(EXPERIMENT_HOME,"dataset")) # Dataset location
    os.environ["EXPERIMENT_HOME"] = EXPERIMENT_HOME
    os.environ["DATA_HOME"] = DATA_HOME
    sys.path.insert(0, EXPERIMENT_HOME)
    sys.path.insert(0, ML_HOME) # Add to path so can load our library
    os.chdir(EXPERIMENT_HOME) # Change working directory to experiment workspace
print("Experiment Home: ", os.path.abspath(os.curdir), "; Data Home:", DATA_HOME)
# Out:
# Experiment Home:  /home/jovyan ; Data Home: /home/jovyan/dataset

# %%
from datetime import datetime
import pandas as pd
import pandas_datareader as pdr
import datetime as dt
import xlrd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
os.chdir("/home/jovyan/dataset/set100.data")
stocks = pd.read_csv('_directory.csv', index_col=0)
print("Stocks count:", len(stocks))
stocks.tail()
# Out:
# Stocks count: 150
#                                            company_name  \
# ticker
# VIBHA   VIBHAVADI MEDICAL CENTER PUBLIC COMPANY LIMITED
# VNG               VANACHAI GROUP PUBLIC COMPANY LIMITED
# WHA              WHA CORPORATION PUBLIC COMPANY LIMITED
# WHAUP    WHA UTILITIES AND POWER PUBLIC COMPANY LIMITED
# WORK     WORKPOINT ENTERTAINMENT PUBLIC COMPANY LIMITED
#
#                        industry                  sector symbol
# ticker
# VIBHA                  Services    Health Care Services  VIBHA
# VNG     Property & Construction  Construction Materials    VNG
# WHA     Property & Construction    Property Development    WHA
# WHAUP                 Resources      Energy & Utilities  WHAUP
# WORK                   Services      Media & Publishing   WORK

# %%
period_start='2014-01-01'
period_end='2014-12-31'
series = {}
for s in stocks.symbol.values:
    df = pd.read_csv("%s.csv" % s, index_col=0)
    # Add column ticker
    df.loc[:,('Date')] = df.index
    df['Ticker'] = s
    
    # Add sector column
    sector = stocks[stocks['symbol']==s].sector.values[0]
    df['Sector'] = sector

    # Add industry column
    industry = stocks[stocks['symbol']==s].industry.values[0]
    df['Industry'] = industry
    
    # Add to dictionary
    series[s] = df[period_start:period_end]

# %%
# Select single stock series for analysis    
ticker = "SCB"
df = series[ticker]
df.index = pd.to_datetime(df.index)
df
# Out:
#             Price        MV         VA       VO    DY        Date Ticker  \
# Date
# 2014-01-01  143.5  487040.3        NaN      NaN  3.48  2014-01-01    SCB
# 2014-01-02  131.5  446312.2  2001558.0  14727.9  3.80  2014-01-02    SCB
# 2014-01-03  132.5  449706.3  2051395.0  15411.3  3.77  2014-01-03    SCB
# 2014-01-06  140.0  475161.3  1740385.0  12798.9  3.57  2014-01-06    SCB
# 2014-01-07  144.0  488737.4  1322406.0   9353.2  3.47  2014-01-07    SCB
# ...           ...       ...        ...      ...   ...         ...    ...
# 2014-12-25  183.0  621158.6   460363.9   2521.7  2.87  2014-12-25    SCB
# 2014-12-26  184.5  626250.0   450219.8   2458.3  2.85  2014-12-26    SCB
# 2014-12-29  183.0  621158.6   485902.8   2633.2  2.87  2014-12-29    SCB
# 2014-12-30  182.0  617764.2   547944.4   2993.7  2.88  2014-12-30    SCB
# 2014-12-31  182.0  617764.2        NaN      NaN  2.88  2014-12-31    SCB
#
#              Sector    Industry
# Date
# 2014-01-01  Banking  Financials
# 2014-01-02  Banking  Financials
# 2014-01-03  Banking  Financials
# 2014-01-06  Banking  Financials
# 2014-01-07  Banking  Financials
# ...             ...         ...
# 2014-12-25  Banking  Financials
# 2014-12-26  Banking  Financials
# 2014-12-29  Banking  Financials
# 2014-12-30  Banking  Financials
# 2014-12-31  Banking  Financials
#
# [261 rows x 9 columns]

# %%
# Stack dataframes together
# https://stackoverflow.com/questions/29351840/stack-two-pandas-data-frames
rows = []
for k, d in series.items():
    rows.append(d)
df = pd.concat(rows, ignore_index=True)
df
# Out:
#        Price        MV       VA       VO   DY        Date Ticker  \
# 0       3.66  17751.00      NaN      NaN  0.0  2014-01-01    AAV
# 1       3.44  16683.99  65373.3  19045.1  0.0  2014-01-02    AAV
# 2       3.42  16586.99  34585.3  10163.8  0.0  2014-01-03    AAV
# 3       3.54  17168.99  41467.2  11936.8  0.0  2014-01-06    AAV
# 4       3.72  18041.99  92143.9  25572.0  0.0  2014-01-07    AAV
# ...      ...       ...      ...      ...  ...         ...    ...
# 33664  29.80  11173.70  12347.5    416.6  0.0  2014-12-25   WORK
# 33665  30.51  11439.74  19288.1    638.1  0.0  2014-12-26   WORK
# 33666  29.80  11173.70   1975.3     65.5  0.0  2014-12-29   WORK
# 33667  29.80  11173.70   3981.8    134.2  0.0  2014-12-30   WORK
# 33668  29.80  11173.70      NaN      NaN  0.0  2014-12-31   WORK
#
#                            Sector  Industry
# 0      Transportation & Logistics  Services
# 1      Transportation & Logistics  Services
# 2      Transportation & Logistics  Services
# 3      Transportation & Logistics  Services
# 4      Transportation & Logistics  Services
# ...                           ...       ...
# 33664          Media & Publishing  Services
# 33665          Media & Publishing  Services
# 33666          Media & Publishing  Services
# 33667          Media & Publishing  Services
# 33668          Media & Publishing  Services
#
# [33669 rows x 9 columns]

# %%
len(series)
# Out:
# 150

# %%
# Pivot table: Value=Price
ptable = df.pivot_table(values='Price', index='Date', columns=['Industry', 'Sector', 'Ticker'])
ptable
# Out:
# Industry   Agro & Food Industry                                            \
# Sector             Agribusiness        Food & Beverage
# Ticker                     GFPT    STA             CBG    CPF  ICHI  KTIS
# Date
# 2014-01-01                 12.8  12.53             NaN  32.00   NaN   NaN
# 2014-01-02                 12.2  11.95             NaN  30.50   NaN   NaN
# 2014-01-03                 12.0  11.56             NaN  30.50   NaN   NaN
# 2014-01-06                 11.9  11.47             NaN  29.25   NaN   NaN
# 2014-01-07                 12.2  11.95             NaN  30.50   NaN   NaN
# ...                         ...    ...             ...    ...   ...   ...
# 2014-12-25                 18.3  12.33           32.75  27.25  20.0  11.1
# 2014-12-26                 18.1  12.33           33.25  27.75  20.1  11.5
# 2014-12-29                 18.1  12.33           33.00  27.50  20.0  11.7
# 2014-12-30                 17.8  12.33           33.50  27.25  20.0  11.6
# 2014-12-31                 17.8  12.33           33.50  27.25  20.0  11.6
#
# Industry                                ...            Technology  \
# Sector                                  ... Electronic Components
# Ticker          M  MALEE   MINT  SAPPE  ...                   SVI
# Date                                    ...
# 2014-01-01  51.25  15.00  18.54    NaN  ...                  4.14
# 2014-01-02  48.25  14.62  17.01    NaN  ...                  4.00
# 2014-01-03  48.75  15.37  16.75    NaN  ...                  4.10
# 2014-01-06  48.00  15.12  18.00    NaN  ...                  3.94
# 2014-01-07  48.75  16.12  18.80    NaN  ...                  4.06
# ...           ...    ...    ...    ...  ...                   ...
# 2014-12-25  57.50  13.75  30.00  34.75  ...                  4.06
# 2014-12-26  57.75  13.87  29.55  33.75  ...                  4.08
# 2014-12-29  56.25  13.75  28.65  33.50  ...                  4.00
# 2014-12-30  58.50  13.75  29.10  33.00  ...                  4.00
# 2014-12-31  58.50  13.75  29.10  33.00  ...                  4.00
#
# Industry                                                                     \
# Sector     Information & Communication Technology
# Ticker                                     ADVANC   DTAC INTUCH   JAS JMART
# Date
# 2014-01-01                                  199.5  97.00  67.75  6.04  8.61
# 2014-01-02                                  187.0  93.00  64.00  5.59  8.18
# 2014-01-03                                  196.0  92.50  65.50  5.41  7.92
# 2014-01-06                                  201.0  95.25  66.00  5.72  7.92
# 2014-01-07                                  210.0  96.25  67.75  5.90  7.80
# ...                                           ...    ...    ...   ...   ...
# 2014-12-25                                  248.0  97.50  78.25  6.58  5.46
# 2014-12-26                                  251.0  97.00  79.00  6.67  5.46
# 2014-12-29                                  249.0  96.75  78.25  6.44  5.35
# 2014-12-30                                  251.0  96.50  78.75  6.62  5.41
# 2014-12-31                                  251.0  96.50  78.75  6.62  5.41
#
# Industry
# Sector
# Ticker     SAMART SAMTEL  THCOM   TRUE
# Date
# 2014-01-01  14.80   12.9  40.50   6.51
# 2014-01-02  14.00   12.1  38.00   5.90
# 2014-01-03  14.10   11.7  36.75   5.82
# 2014-01-06  14.90   12.0  36.25   5.99
# 2014-01-07  14.80   12.4  36.75   6.17
# ...           ...    ...    ...    ...
# 2014-12-25  39.00   21.6  35.50  11.10
# 2014-12-26  38.25   21.8  35.25  10.80
# 2014-12-29  39.00   22.2  34.75  10.90
# 2014-12-30  39.25   22.7  34.75  10.90
# 2014-12-31  39.25   22.7  34.75  10.90
#
# [261 rows x 129 columns]

# %%
len(series)
# Out:
# 150

# %%
cols = []
for c in ptable.columns:
    cols.append(c[2])
# Determine what is missing
cols_set = set(cols)
series_set = set(series.keys())

# %%
# These tickers are in series, but not in columns

series_set.difference(cols_set)
# Out:
# {'AWC',
#  'BCPG',
#  'BEM',
#  'BGRIM',
#  'BPP',
#  'COM7',
#  'GGC',
#  'GPSC',
#  'GULF',
#  'JWD',
#  'ORI',
#  'OSP',
#  'PLANB',
#  'PLAT',
#  'PRM',
#  'SCN',
#  'SPRC',
#  'TKN',
#  'TOA',
#  'TPIPP',
#  'WHAUP'}

# %%
series['TOA']
# Out:
# Empty DataFrame
# Columns: [Price, MV, VA, VO, DY, Date, Ticker, Sector, Industry]
# Index: []

# %%
series['SPRC']
# Out:
# Empty DataFrame
# Columns: [Price, MV, VA, VO, DY, Date, Ticker, Sector, Industry]
# Index: []
