# %%
import sys, os, os.path
if not 'EXPERIMENT_HOME' in os.environ: # Configure local paths if not already defined
    ML_HOME = os.path.abspath(os.path.join("..", "ml_home")) # ML workspace
    EXPERIMENT_HOME = os.path.abspath(os.path.join(ML_HOME, "..")) # Experiment workspace
    DATA_HOME = os.path.abspath(os.path.join(EXPERIMENT_HOME,"dataset")) # Dataset location
    os.environ["EXPERIMENT_HOME"] = EXPERIMENT_HOME
    os.environ["DATA_HOME"] = DATA_HOME
    sys.path.insert(0, EXPERIMENT_HOME)
    sys.path.insert(0, ML_HOME) # Add to path so can load our library
    os.chdir(EXPERIMENT_HOME) # Change working directory to experiment workspace
print("Experiment Home: ", os.path.abspath(os.curdir), "; Data Home:", DATA_HOME)
# Out:
# Experiment Home:  /home/jovyan/dataset/Datastream ; Data Home: /home/jovyan/dataset

# %%
from datetime import datetime
import pandas as pd
import pandas_datareader as pdr
import datetime as dt
import xlrd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Out:
# /home/jovyan/dataset/Datastream

# %%
import sqlite3
DB_FILE = os.path.join(os.environ['DATA_HOME'], 'stock.db')
cnx = sqlite3.connect(DB_FILE)

# %%
os.chdir('/home/jovyan/dataset/Datastream')

# %%
import shutil
src = '/home/jovyan/dataset/Datastream/SET100_MissingData.xlsm'
dest = '/home/jovyan/dataset/Datastream/SET100_FullData.xlsm'
# shutil.copy2(src, dest)
# Out:
# '/home/jovyan/dataset/Datastream/SET100_FullData.xlsm'

# %%
# !ls
# Out:
# DataDict_Static.xls  LBNGK100		     set100_daily_facts.csv.gz
# DataTypes_DFO.xlsx   LBNGKSET		     SET100_FullData.xlsm
# Data.xlsx	     set100_daily_facts.csv  SET100_MissingData.xlsm

# %%
fname = '/home/jovyan/dataset/Datastream/SET100_FullData.xlsm'

# %%
up = {}
for i in range(2,18):
    df_up = pd.read_sql("SELECT constituents FROM dataset_set100 WHERE update_id='Update_%s'" % i, cnx)
    stocks = set(df_up[0:1].values[0][0].replace(" ",",").split(','))
    up[i] = stocks

# %%
# What are the inclusion and exclusion for each update.
all_tickers = set()
idx = []
for k, v in up.items():
    id = 'Update_%s' % k
    try:
        exclusion = up[k-1].difference(up[k])
        inclusion = up[k].difference(up[k-1])
        all_tickers.update(v)
        print(id, exclusion, inclusion)
        idx.append({'update_seq': id,
                    'set100': ",".join(sorted(list(v))),
                    'inclusion': ",".join(sorted(list(inclusion))),
                    'exclusion': ",".join(sorted(list(exclusion)))
                   })
    except:
        pass
# Out:
# Update_3 {'THRE', 'BLA', 'MCOT', 'WHA', 'ESSO', 'SRICHA', 'RS', 'TASCO', 'NYT', 'DCC'} {'ICHI', 'PTG', 'SAWAD', 'DEMCO', 'SIM', 'SF', 'KTIS', 'SGP', 'HANA', 'ANAN'}
# Update_4 {'HEMRAJ'} {'IFEC'}
# Update_5 {'BIGC', 'PTG', 'BJC', 'BAY', 'NOK', 'STA', 'SIM', 'MEGA', 'IFEC', 'KTIS', 'THREL', 'SCCC', 'BCH'} {'BEAUTY', 'LHBANK', 'WHA', 'CBG', 'CKP', 'BA', 'UNIQ', 'SAPPE', 'RS', 'S', 'ASP', 'U', 'MONO'}
# Update_6 {'GFPT', 'LOXLEY', 'GLOBAL', 'ASP', 'SAPPE', 'MC', 'U', 'TUF', 'DEMCO', 'SF', 'RATCH', 'SGP', 'PSL', 'MONO', 'ERW'} {'WORK', 'BLA', 'CHG', 'PTG', 'GPSC', 'SCN', 'PLAT', 'PLANB', 'TU', 'VNG', 'TASCO', 'EPG', 'SAMTEL', 'SCCC', 'GL'}
# Update_7 {'BECL', 'BMCL', 'BGH'} {'BDMS', 'SGP', 'BEM'}
# Update_8 {'JAS', 'M', 'UV', 'TICON', 'SCN', 'PLAT', 'SAMTEL', 'EARTH', 'SCCC'} {'GLOBAL', 'JWD', 'TRC', 'MTLS', 'TVO', 'IFEC', 'COM7', 'BCH', 'ERW'}
# Update_9 {'PS'} {'PSH'}
# Update_10 {'WORK', 'SVI', 'JWD', 'TRC', 'ERW', 'BJCHI', 'ANAN', 'GL'} {'SUPER', 'TKN', 'SCN', 'BIG', 'SPRC', 'VIBHA', 'THANI', 'KAMART'}
# Update_11 {'SAMART', 'ICHI', 'SCN', 'TTCL', 'TTW', 'HANA', 'RS', 'VNG', 'IFEC', 'SGP', 'SPCG', 'VIBHA', 'KAMART'} {'WORK', 'GFPT', 'ANAN', 'EA', 'BCPG', 'PTL', 'MEGA', 'RATCH', 'BPP', 'BJC', 'MALEE', 'SCCC', 'MONO'}
# Update_12 {'LHBANK', 'BLA', 'THANI', 'STPI', 'DELTA', 'PTL', 'VGI', 'PLANB', 'S', 'RATCH', 'GLOW', 'MALEE', 'SCCC'} {'UV', 'TPIPP', 'JWD', 'JMART', 'ESSO', 'WHAUP', 'MC', 'PSL', 'STA', 'ORI', 'SGP', 'HANA', 'GGC'}
# Update_13 {'THCOM', 'ANAN', 'JWD', 'JMART', 'MONO', 'BIG', 'BA', 'UNIQ', 'BEC', 'MC', 'TTA'} {'BLA', 'BGRIM', 'TTW', 'DELTA', 'TOA', 'RS', 'PRM', 'RATCH', 'GLOW', 'THANI', 'ERW'}
# Update_14 {'TPIPL', 'BLA', 'UV', 'LPN', 'ITD', 'GGC'} {'AEONTS', 'GULF', 'PLANB', 'MBK', 'GOLD', 'ANAN'}
# Update_15 {'GLOW'} {'BEC'}
# Update_16 {'WORK', 'GOLD', 'WHAUP'} {'JAS', 'JMT', 'OSP'}
# Update_17 {'BEAUTY'} {'AWC'}

# %%
len(all_tickers)
# Out:
# 163

# %% [markdown]
# Create sheet
# https://stackoverflow.com/questions/19189048/writing-creating-a-worksheet-using-xlrd-and-xlwt-in-python

# %%
wb = xlrd.open_workbook(fname)
existing_sheets = wb.sheet_names()
existing_sheets
# Out:
# ['REQUEST_TABLE',
#  'BECL',
#  'BIGC',
#  'BMCL',
#  'EARTH',
#  'GLOW',
#  'GOLD',
#  'HEMRAJ',
#  'IFEC',
#  'ROBINS',
#  'GL',
#  'WHAUP',
#  'JMART']

# %%
s = wb.sheets()[2] # Choose sheet by index to read data to data frame.

# %%
# Date index
s1 = pd.Series(s.col(0)[8:]) # observation starts at row 8
s1 = s1.apply(lambda x: datetime(*xlrd.xldate_as_tuple(x.value, wb.datemode)))
cols = {'Date':s1} # columns of data
for j in range(1, s.ncols):
    locCode = s.col(j)[3:4][0].value
    dataType = s.col(j)[4:5][0].value
    companyName = s.col(j)[5:6][0].value
    listedDate = datetime(*xlrd.xldate_as_tuple(s.col(j)[6:7][0].value, wb.datemode))
    c = s.col(j)
    # print("{}".format(c[3].value)) # Print each column in data file
    # Convert spreadsheet market cap value to python
    s2 = pd.Series(c[8:]) # observation starts at row 8
    s2 = s2.apply(lambda x: x.value)
    cols[dataType] = s2
df = pd.concat(cols, axis=1)

# %%
# s.col(0)[8:]  s.col(1)[8:]
df
# Out:
#            date    DY   EPS        MV      P   PH   PL   PO       VA     VO  \
# 0    2015-01-01  1.08  8.92  195524.9  237.0   NA   NA   NA       NA     NA
# 1    2015-01-02  1.08  8.92  195524.9  237.0   NA   NA   NA       NA     NA
# 2    2015-01-05  1.05  8.92  199649.9  242.0  242  233  233  86873.9  363.4
# 3    2015-01-06  1.07  8.92  196349.9  238.0  242  236  240  90008.1  376.8
# 4    2015-01-07  1.05  8.92  201299.9  244.0  245  237  237  41911.4  172.8
# ...         ...   ...   ...       ...    ...  ...  ...  ...      ...    ...
# 1299 2019-12-25  0.96  7.09  163349.9  198.0   NA   NA   NA       NA     NA
# 1300 2019-12-26  0.96  7.09  163349.9  198.0   NA   NA   NA       NA     NA
# 1301 2019-12-27  0.96  7.09  163349.9  198.0   NA   NA   NA       NA     NA
# 1302 2019-12-30  0.96  7.09  163349.9  198.0   NA   NA   NA       NA     NA
# 1303 2019-12-31  0.96  7.09  163349.9  198.0   NA   NA   NA       NA     NA
#
#       PTBV    PE      PI       RI  MTBV      NOSH         DWTA  053E
# 0     4.19  26.6  1351.7  2112.86  4.19  825000.0  102088552.0  0.00
# 1     4.19  26.6  1351.7  2112.86  4.19  825000.0  102088552.0  0.00
# 2     4.28  27.1  1380.2  2157.44  4.28  825000.0  102088552.0  0.40
# 3     4.21  26.7  1357.4  2121.78  4.21  825000.0  102088552.0  0.39
# 4     4.31  27.4  1391.6  2175.27  4.31  825000.0  102088552.0  0.86
# ...    ...   ...     ...      ...   ...       ...          ...   ...
# 1299  3.23  27.9  1129.2  1819.24  3.23  825000.0   91481022.0  0.00
# 1300  3.23  27.9  1129.2  1819.24  3.23  825000.0   91481022.0  0.00
# 1301  3.23  27.9  1129.2  1819.24  3.23  825000.0   91481022.0  0.00
# 1302  3.23  27.9  1129.2  1819.24  3.23  825000.0   91481022.0  0.00
# 1303  3.23  27.9  1129.2  1819.24  3.23  825000.0   91481022.0  0.00
#
# [1304 rows x 18 columns]

# %%
companyName
# Out:
# 'BIG C SUPERCENTER DEAD - DELIST.28/09/17'

# %%
for t in sorted(all_tickers):
    b = "='%s'!$A$1" % t
    print(b)
# Out:
# ='AAV'!$A$1
# ='ADVANC'!$A$1
# ='AEONTS'!$A$1
# ='AMATA'!$A$1
# ='ANAN'!$A$1
# ='AOT'!$A$1
# ='AP'!$A$1
# ='ASP'!$A$1
# ='AWC'!$A$1
# ='BA'!$A$1
# ='BANPU'!$A$1
# ='BAY'!$A$1
# ='BBL'!$A$1
# ='BCH'!$A$1
# ='BCP'!$A$1
# ='BCPG'!$A$1
# ='BDMS'!$A$1
# ='BEAUTY'!$A$1
# ='BEC'!$A$1
# ='BECL'!$A$1
# ='BEM'!$A$1
# ='BGH'!$A$1
# ='BGRIM'!$A$1
# ='BH'!$A$1
# ='BIG'!$A$1
# ='BIGC'!$A$1
# ='BJC'!$A$1
# ='BJCHI'!$A$1
# ='BLA'!$A$1
# ='BLAND'!$A$1
# ='BMCL'!$A$1
# ='BPP'!$A$1
# ='BTS'!$A$1
# ='CBG'!$A$1
# ='CENTEL'!$A$1
# ='CHG'!$A$1
# ='CK'!$A$1
# ='CKP'!$A$1
# ='COM7'!$A$1
# ='CPALL'!$A$1
# ='CPF'!$A$1
# ='CPN'!$A$1
# ='DELTA'!$A$1
# ='DEMCO'!$A$1
# ='DTAC'!$A$1
# ='EA'!$A$1
# ='EARTH'!$A$1
# ='EGCO'!$A$1
# ='EPG'!$A$1
# ='ERW'!$A$1
# ='ESSO'!$A$1
# ='GFPT'!$A$1
# ='GGC'!$A$1
# ='GL'!$A$1
# ='GLOBAL'!$A$1
# ='GLOW'!$A$1
# ='GOLD'!$A$1
# ='GPSC'!$A$1
# ='GULF'!$A$1
# ='GUNKUL'!$A$1
# ='HANA'!$A$1
# ='HEMRAJ'!$A$1
# ='HMPRO'!$A$1
# ='ICHI'!$A$1
# ='IFEC'!$A$1
# ='INTUCH'!$A$1
# ='IRPC'!$A$1
# ='ITD'!$A$1
# ='IVL'!$A$1
# ='JAS'!$A$1
# ='JMART'!$A$1
# ='JMT'!$A$1
# ='JWD'!$A$1
# ='KAMART'!$A$1
# ='KBANK'!$A$1
# ='KCE'!$A$1
# ='KKP'!$A$1
# ='KTB'!$A$1
# ='KTC'!$A$1
# ='KTIS'!$A$1
# ='LH'!$A$1
# ='LHBANK'!$A$1
# ='LOXLEY'!$A$1
# ='LPN'!$A$1
# ='M'!$A$1
# ='MAJOR'!$A$1
# ='MALEE'!$A$1
# ='MBK'!$A$1
# ='MC'!$A$1
# ='MEGA'!$A$1
# ='MINT'!$A$1
# ='MONO'!$A$1
# ='MTLS'!$A$1
# ='NOK'!$A$1
# ='ORI'!$A$1
# ='OSP'!$A$1
# ='PLANB'!$A$1
# ='PLAT'!$A$1
# ='PRM'!$A$1
# ='PS'!$A$1
# ='PSH'!$A$1
# ='PSL'!$A$1
# ='PTG'!$A$1
# ='PTL'!$A$1
# ='PTT'!$A$1
# ='PTTEP'!$A$1
# ='PTTGC'!$A$1
# ='QH'!$A$1
# ='RATCH'!$A$1
# ='ROBINS'!$A$1
# ='RS'!$A$1
# ='S'!$A$1
# ='SAMART'!$A$1
# ='SAMTEL'!$A$1
# ='SAPPE'!$A$1
# ='SAWAD'!$A$1
# ='SCB'!$A$1
# ='SCC'!$A$1
# ='SCCC'!$A$1
# ='SCN'!$A$1
# ='SF'!$A$1
# ='SGP'!$A$1
# ='SIM'!$A$1
# ='SIRI'!$A$1
# ='SPALI'!$A$1
# ='SPCG'!$A$1
# ='SPRC'!$A$1
# ='STA'!$A$1
# ='STEC'!$A$1
# ='STPI'!$A$1
# ='SUPER'!$A$1
# ='SVI'!$A$1
# ='TASCO'!$A$1
# ='TCAP'!$A$1
# ='THAI'!$A$1
# ='THANI'!$A$1
# ='THCOM'!$A$1
# ='THREL'!$A$1
# ='TICON'!$A$1
# ='TISCO'!$A$1
# ='TKN'!$A$1
# ='TMB'!$A$1
# ='TOA'!$A$1
# ='TOP'!$A$1
# ='TPIPL'!$A$1
# ='TPIPP'!$A$1
# ='TRC'!$A$1
# ='TRUE'!$A$1
# ='TTA'!$A$1
# ='TTCL'!$A$1
# ='TTW'!$A$1
# ='TU'!$A$1
# ='TUF'!$A$1
# ='TVO'!$A$1
# ='U'!$A$1
# ='UNIQ'!$A$1
# ='UV'!$A$1
# ='VGI'!$A$1
# ='VIBHA'!$A$1
# ='VNG'!$A$1
# ='WHA'!$A$1
# ='WHAUP'!$A$1
# ='WORK'!$A$1
