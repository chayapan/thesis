# %%
import sys, os, os.path
if not 'EXPERIMENT_HOME' in os.environ: # Configure local paths if not already defined
    ML_HOME = os.path.abspath(os.path.join("/home/jovyan", "ml_home")) # ML workspace
    sys.path.insert(0, ML_HOME) # Add to path so can load our library
    EXPERIMENT_HOME = os.path.abspath(os.path.join(ML_HOME, "..")) # Experiment workspace
from experiment import init_experiment
db_engine = init_experiment(EXPERIMENT_HOME)
# Out:
# Experiment Home:  /home/jovyan ; Data Home: /home/jovyan/dataset ;
# Database: Engine(postgresql://datauser:***@172.18.0.1:5432/stockdb)

# %%
from datetime import datetime
import numpy as np
import pandas as pd
import pandas_datareader as pdr
import datetime as dt
import xlrd
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # Raw Data

# %%
# First sheet list all companies
# VO sheet contains VO data

# Row 3  LOC;  Row 4  Datatype  Row 5 Name

# %%
from data.snapshot import SET100

# %%
sm = SET100()
sm.symbols
# Out:
# array(['AAV', 'ADVANC', 'AEONTS', 'AMATA', 'ANAN', 'AOT', 'AP', 'ASP',
#        'AWC', 'BA', 'BANPU', 'BAY', 'BBL', 'BCH', 'BCP', 'BCPG', 'BDMS',
#        'BEAUTY', 'BEC', 'BECL', 'BEM', 'BGH', 'BGRIM', 'BH', 'BIG',
#        'BIGC', 'BJC', 'BJCHI', 'BLA', 'BLAND', 'BMCL', 'BPP', 'BTS',
#        'CBG', 'CENTEL', 'CHG', 'CK', 'CKP', 'COM7', 'CPALL', 'CPF', 'CPN',
#        'DELTA', 'DEMCO', 'DTAC', 'EA', 'EARTH', 'EGCO', 'EPG', 'ERW',
#        'ESSO', 'GFPT', 'GGC', 'GL', 'GLOBAL', 'GLOW', 'GOLD', 'GPSC',
#        'GULF', 'GUNKUL', 'HANA', 'HEMRAJ', 'HMPRO', 'ICHI', 'IFEC',
#        'INTUCH', 'IRPC', 'ITD', 'IVL', 'JAS', 'JMART', 'JMT', 'JWD',
#        'KAMART', 'KBANK', 'KCE', 'KKP', 'KTB', 'KTC', 'KTIS', 'LH',
#        'LHBANK', 'LOXLEY', 'LPN', 'M', 'MAJOR', 'MALEE', 'MBK', 'MC',
#        'MEGA', 'MINT', 'MONO', 'MTLS', 'NOK', 'ORI', 'OSP', 'PLANB',
#        'PLAT', 'PRM', 'PS', 'PSH', 'PSL', 'PTG', 'PTL', 'PTT', 'PTTEP',
# ...

# %%
sm.sheets[0]
# Out:
#      Unnamed: 0 Symbol In SET100 Constituent             Company Name  \
# 0             1                          AAV            ASIA AVIATION
# 1             2                       ADVANC       ADVANCED INFO SER.
# 2             3                       AEONTS  AE.THANA SINSAP (THAI.)
# 3             4                        AMATA                    AMATA
# 4             5                         ANAN       ANANDA DEVELOPMENT
# ..          ...                          ...                      ...
# 158         159                        VIBHA        VIBHAVADI MEDICAL
# 159         160                          VNG           VANACHAI GROUP
# 160         161                          WHA                      WHA
# 161         162                        WHAUP  WHA UTILITIES AND POWER
# 162         163                         WORK  WORKPOINT ENTERTAINMENT
#
#     Datastream Mnemonic Remark
# 0                Q:AAVP    NaN
# 1                 Q:AIS    NaN
# ...

# %%
sm.VO
# Out:
#              TH:AAV TH:ADVANC TH:AEONTS TH:AMATA TH:ANAN   TH:AOT    TH:AP  \
# LOC
# 2015-01-01      NaN       NaN       NaN      NaN     NaN      NaN      NaN
# 2015-01-02      NaN       NaN       NaN      NaN     NaN      NaN      NaN
# 2015-01-05  16567.4      5233      54.2   2265.6  3953.1  24974.6   8554.4
# 2015-01-06  59230.2    4386.6        85   3227.5  7590.1  24310.7  14844.8
# 2015-01-07  24048.5   11060.8        54   1495.1  9863.9  20686.3  16486.6
# ...             ...       ...       ...      ...     ...      ...      ...
# 2019-12-25   1739.2      2424      74.7   5157.9  2964.2   7226.9   7085.2
# 2019-12-26   2558.2    1685.5      18.7   7070.9  7358.9  15170.9  25276.4
# 2019-12-27   4667.2      3997      94.5   7722.3  4017.6  22611.9   9339.9
# 2019-12-30   6361.1    2624.8     233.7   1204.8  2086.5   9374.1   7620.2
# 2019-12-31      NaN       NaN       NaN      NaN     NaN      NaN      NaN
#
# ...

# %%
sm.VA
# Out:
#              TH:AAV TH:ADVANC TH:AEONTS TH:AMATA  TH:ANAN   TH:AOT    TH:AP  \
# LOC
# 2015-01-01      NaN       NaN       NaN      NaN      NaN      NaN      NaN
# 2015-01-02      NaN       NaN       NaN      NaN      NaN      NaN      NaN
# 2015-01-05  71287.9   1308087    5850.2    35315  13019.1   686775  51466.6
# 2015-01-06   265539   1084522    9177.9    50177  24647.7   657020  87288.1
# 2015-01-07   110609   2711075    5838.2  23392.6  32507.6   579136  99237.1
# ...             ...       ...       ...      ...      ...      ...      ...
# 2019-12-25   3756.8    519304   14036.2   102390   7178.6   532603    49411
# 2019-12-26   5533.2    361643    3534.7   140379  18599.6  1131125   184269
# 2019-12-27  10248.2    856595   17902.9   155459  10436.8  1683086  68426.3
# 2019-12-30    14203    561638   44498.4  24091.7   5461.2   697589  56553.7
# 2019-12-31      NaN       NaN       NaN      NaN      NaN      NaN      NaN
#
# ...

# %%
sm.NOSH
# Out:
#              TH:AAV TH:ADVANC TH:AEONTS TH:AMATA  TH:ANAN    TH:AOT    TH:AP  \
# LOC
# 2015-01-01  4849999   2973094    250000  1067000  3332999   1428570  3145896
# 2015-01-02  4849999   2973094    250000  1067000  3332999   1428570  3145896
# 2015-01-05  4849999   2973094    250000  1067000  3332999   1428570  3145896
# 2015-01-06  4849999   2973094    250000  1067000  3332999   1428570  3145896
# 2015-01-07  4849999   2973094    250000  1067000  3332999   1428570  3145896
# ...             ...       ...       ...      ...      ...       ...      ...
# 2019-12-25  4849999   2973178    250000  1109680  3332994  14285700  3145889
# 2019-12-26  4849999   2973178    250000  1109680  3332994  14285700  3145889
# 2019-12-27  4849999   2973178    250000  1109680  3332994  14285700  3145889
# 2019-12-30  4849999   2973178    250000  1109680  3332994  14285700  3145889
# 2019-12-31  4849999   2973178    250000  1109680  3332994  14285700  3145889
#
# ...

# %%
sm.MV
# Out:
#            TH:AAV TH:ADVANC TH:AEONTS TH:AMATA  TH:ANAN   TH:AOT    TH:AP  \
# LOC
# 2015-01-01  20855    746247     27125  16751.9  10932.2   402857  18718.1
# 2015-01-02  20855    746247     27125  16751.9  10932.2   402857  18718.1
# 2015-01-05  20855    740300     27000  17178.7  10798.9   390000  18718.1
# 2015-01-06  22019    734354     27125  17178.7  10865.6   388571  18560.8
# 2015-01-07  22213    752193     27250  17178.7  11132.2   404286  18875.4
# ...           ...       ...       ...      ...      ...      ...      ...
# 2019-12-25  10476    639233     47125  22304.6  8065.84  1057141  22021.2
# 2019-12-26  10476    639233     47125  22193.6  8532.46  1067855  23122.3
# 2019-12-27  10670    636260     47375  22415.5  8799.11  1060712  23122.3
# 2019-12-30  10864    633287     47750  22304.6  8732.44  1060712  23436.9
# 2019-12-31  10864    633287     47750  22304.6  8732.44  1060712  23436.9
#
# ...

# %%
sm.P
# Out:
#            TH:AAV TH:ADVANC TH:AEONTS TH:AMATA TH:ANAN TH:AOT TH:AP TH:ASP  \
# LOC
# 2015-01-01    4.3       251     108.5    15.29    3.28   28.2  5.95   4.08
# 2015-01-02    4.3       251     108.5    15.29    3.28   28.2  5.95   4.08
# 2015-01-05    4.3       249       108    15.67    3.24   27.3  5.95   4.16
# 2015-01-06   4.54       247     108.5    15.67    3.26   27.2   5.9   4.12
# 2015-01-07   4.58       253       109    15.67    3.34   28.3     6    4.2
# ...           ...       ...       ...      ...     ...    ...   ...    ...
# 2019-12-25   2.16       215     188.5    19.94    2.42     74     7   1.69
# 2019-12-26   2.16       215     188.5    19.84    2.56  74.75  7.35   1.71
# 2019-12-27    2.2       214     189.5    20.04    2.64  74.25  7.35   1.74
# 2019-12-30   2.24       213       191    19.94    2.62  74.25  7.45   1.74
# 2019-12-31   2.24       213       191    19.94    2.62  74.25  7.45   1.74
#
# ...

# %%
sm.PH
# Out:
#            TH:AAV TH:ADVANC TH:AEONTS TH:AMATA TH:ANAN TH:AOT TH:AP TH:ASP  \
# LOC
# 2015-01-01    NaN       NaN       NaN      NaN     NaN    NaN   NaN    NaN
# 2015-01-02    NaN       NaN       NaN      NaN     NaN    NaN   NaN    NaN
# 2015-01-05   4.32       254       108    15.67    3.36     28  6.05    4.2
# 2015-01-06   4.56       250     108.5    15.77    3.32   27.4  5.95   4.14
# 2015-01-07   4.64       253       109    15.77    3.36   28.3   6.1    4.3
# ...           ...       ...       ...      ...     ...    ...   ...    ...
# 2019-12-25   2.18       216     189.5    19.94    2.46     74  7.05   1.69
# 2019-12-26   2.18       216     189.5    20.04    2.58     75  7.45   1.73
# 2019-12-27   2.22       216       190    20.33    2.64  75.25   7.4   1.75
# 2019-12-30   2.26       216     191.5    20.13    2.64  74.75  7.55   1.76
# 2019-12-31    NaN       NaN       NaN      NaN     NaN    NaN   NaN    NaN
#
# ...

# %%
sm.PL
# Out:
#            TH:AAV TH:ADVANC TH:AEONTS TH:AMATA TH:ANAN TH:AOT TH:AP TH:ASP  \
# LOC
# 2015-01-01    NaN       NaN       NaN      NaN     NaN    NaN   NaN    NaN
# 2015-01-02    NaN       NaN       NaN      NaN     NaN    NaN   NaN    NaN
# 2015-01-05   4.28       247     107.5    15.29    3.24   27.2  5.95   4.04
# 2015-01-06   4.34       245       107    15.19     3.2   26.7   5.8    4.1
# 2015-01-07   4.56       240       108    15.48    3.22   27.5  5.85   4.14
# ...           ...       ...       ...      ...     ...    ...   ...    ...
# 2019-12-25   2.14       212     186.5    19.74    2.38     73   6.9   1.64
# 2019-12-26   2.14       214       188    19.74    2.42  73.75     7   1.69
# 2019-12-27   2.16       213     188.5    19.84    2.52  73.75  7.25   1.72
# 2019-12-30    2.2       213       189    19.94     2.6  74.25   7.3   1.72
# 2019-12-31    NaN       NaN       NaN      NaN     NaN    NaN   NaN    NaN
#
# ...

# %%
sm.PO
# Out:
#            TH:AAV TH:ADVANC TH:AEONTS TH:AMATA TH:ANAN TH:AOT TH:AP TH:ASP  \
# LOC
# 2015-01-01    NaN       NaN       NaN      NaN     NaN    NaN   NaN    NaN
# 2015-01-02    NaN       NaN       NaN      NaN     NaN    NaN   NaN    NaN
# 2015-01-05    4.3       252     107.5    15.29    3.28     28  6.05   4.08
# 2015-01-06   4.34       246       107    15.48    3.22   26.9  5.85   4.12
# 2015-01-07   4.62       246       109    15.77    3.26   27.5  5.85   4.16
# ...           ...       ...       ...      ...     ...    ...   ...    ...
# 2019-12-25   2.14       213     187.5    19.84    2.42  73.25   6.9   1.65
# 2019-12-26   2.18       216       188    19.94    2.42  73.75   7.1   1.69
# 2019-12-27   2.18       216     189.5    19.84    2.56  75.25  7.35   1.72
# 2019-12-30   2.22       215       189    20.04    2.64  74.75  7.35   1.76
# 2019-12-31    NaN       NaN       NaN      NaN     NaN    NaN   NaN    NaN
#
# ...

# %%
sm.MACD
# Out:
#            TH:AAV TH:ADVANC TH:AEONTS TH:AMATA TH:ANAN TH:AOT TH:AP TH:ASP  \
# LOC
# 2015-01-01      0         0         0        0       0      0     0      0
# 2015-01-02      0         0         0        0       0      0     0      0
# 2015-01-05      0     -0.16     -0.04     0.03       0  -0.07     0   0.01
# 2015-01-06   0.02     -0.44     -0.03     0.06       0  -0.14     0   0.01
# 2015-01-07   0.04     -0.18      0.02     0.07       0   -0.1     0   0.02
# ...           ...       ...       ...      ...     ...    ...   ...    ...
# 2019-12-25  -0.06     -1.66     -2.41    -0.88   -0.13  -0.83  0.07  -0.03
# 2019-12-26  -0.06     -1.56     -2.28    -0.85   -0.12  -0.76  0.11  -0.03
# 2019-12-27  -0.05     -1.55     -2.08    -0.81    -0.1  -0.73  0.13  -0.02
# 2019-12-30  -0.04      -1.6     -1.77    -0.77   -0.09  -0.71  0.16  -0.01
# 2019-12-31  -0.04     -1.62     -1.51    -0.73   -0.08  -0.68  0.18      0
#
# ...

# %% [markdown]
# # Prepare Dimensional Model (Data Cube)
#
# Get measure for each stock on each date. Null value will be droped here.

# %%
def get_measure(df, col_name):
    for c in df.columns:
        rows = df[c] # c = company name
        keyx = rows.index.values # time index
        vals = rows.values # value is the measures
        measure = pd.DataFrame(data={'stock':c, 'date':keyx, col_name: vals})
        yield measure

def reduce_fetch_frame(df, col):
    g = get_measure(df, col) # yield chunk: one stock per chunk
    s_df = next(g)  #  start iterator
    for s in g:  # run remaining
        s_df = s_df.append(s)
    return s_df # finish with the data frame that appended all chunks
        
def make_index(df):
    arrays = [df['stock'].values, df['date'].values]
    tuples = list(zip(*arrays))
    # tuples
    index = pd.MultiIndex.from_tuples(tuples, names=['stock','date']) # create index. See pandas doc.
    df.index = index
    return df
        
# g_MACD = get_measure(sm.MACD, 'MACD') # Use generator pattern!

# Test
# g = get_measure(sm.MACD, 'MACD') # will return MACD for one company
# next(g)


s_macd = reduce_fetch_frame(sm.MACD, 'MACD')
s_VO = reduce_fetch_frame(sm.VO, 'VO')
s_VA = reduce_fetch_frame(sm.VA, 'VA')
s_NOSH = reduce_fetch_frame(sm.NOSH, 'NOSH')
s_MV = reduce_fetch_frame(sm.MV, 'MV')
s_P = reduce_fetch_frame(sm.P, 'P')
s_PH = reduce_fetch_frame(sm.PH, 'PH')
s_PL = reduce_fetch_frame(sm.PL, 'PL')
s_PO = reduce_fetch_frame(sm.PO, 'PO')

s_PI = reduce_fetch_frame(sm.PI, 'PI')
s_RI = reduce_fetch_frame(sm.RI, 'RI')
s_DY = reduce_fetch_frame(sm.DY, 'DY')

# %%
s_P = make_index(s_P)
s_VO = make_index(s_VO)
s_VA = make_index(s_VA)
s_NOSH = make_index(s_NOSH)
s_MV = make_index(s_MV)
s_MACD = make_index(s_macd)

s_PH = make_index(s_PH)
s_PL = make_index(s_PL)
s_PO = make_index(s_PO)

s_PI = make_index(s_PI)
s_RI = make_index(s_RI)
s_DY = make_index(s_DY)

# %%
s_MACD
# Out:
#                       stock       date  MACD
# stock   date
# TH:AAV  2015-01-01   TH:AAV 2015-01-01     0
#         2015-01-02   TH:AAV 2015-01-02     0
#         2015-01-05   TH:AAV 2015-01-05     0
#         2015-01-06   TH:AAV 2015-01-06  0.02
#         2015-01-07   TH:AAV 2015-01-07  0.04
# ...                     ...        ...   ...
# TH:WORK 2019-12-25  TH:WORK 2019-12-25 -0.69
#         2019-12-26  TH:WORK 2019-12-26 -0.62
#         2019-12-27  TH:WORK 2019-12-27 -0.55
#         2019-12-30  TH:WORK 2019-12-30 -0.49
#         2019-12-31  TH:WORK 2019-12-31 -0.43
#
# [208640 rows x 3 columns]

# %%
s_P
# Out:
#                       stock       date     P
# stock   date
# TH:AAV  2015-01-01   TH:AAV 2015-01-01   4.3
#         2015-01-02   TH:AAV 2015-01-02   4.3
#         2015-01-05   TH:AAV 2015-01-05   4.3
#         2015-01-06   TH:AAV 2015-01-06  4.54
#         2015-01-07   TH:AAV 2015-01-07  4.58
# ...                     ...        ...   ...
# TH:WORK 2019-12-25  TH:WORK 2019-12-25  13.6
#         2019-12-26  TH:WORK 2019-12-26  13.9
#         2019-12-27  TH:WORK 2019-12-27  14.1
#         2019-12-30  TH:WORK 2019-12-30    14
#         2019-12-31  TH:WORK 2019-12-31    14
#
# [208640 rows x 3 columns]

# %%
s_PH
# Out:
#                       stock       date    PH
# stock   date
# TH:AAV  2015-01-01   TH:AAV 2015-01-01   NaN
#         2015-01-02   TH:AAV 2015-01-02   NaN
#         2015-01-05   TH:AAV 2015-01-05  4.32
#         2015-01-06   TH:AAV 2015-01-06  4.56
#         2015-01-07   TH:AAV 2015-01-07  4.64
# ...                     ...        ...   ...
# TH:WORK 2019-12-25  TH:WORK 2019-12-25  13.8
#         2019-12-26  TH:WORK 2019-12-26  14.1
#         2019-12-27  TH:WORK 2019-12-27  14.3
#         2019-12-30  TH:WORK 2019-12-30  14.2
#         2019-12-31  TH:WORK 2019-12-31   NaN
#
# [208640 rows x 3 columns]

# %%
# Combine all attributes

facts = pd.concat([s_VO, s_MV, s_VA, s_NOSH, s_P, s_PO, s_PH, s_PL, s_MACD, s_PI, s_RI, s_DY], axis=1).reindex(s_MV.index)[['VO', 'MV', 'VA', 'NOSH', 'P', 'PO', 'PH', 'PL', 'MACD', 'PI', 'RI', 'DY']]
facts
# Out:
#                          VO       MV       VA     NOSH     P    PO    PH  \
# stock   date
# TH:AAV  2015-01-01      NaN    20855      NaN  4849999   4.3   NaN   NaN
#         2015-01-02      NaN    20855      NaN  4849999   4.3   NaN   NaN
#         2015-01-05  16567.4    20855  71287.9  4849999   4.3   4.3  4.32
#         2015-01-06  59230.2    22019   265539  4849999  4.54  4.34  4.56
#         2015-01-07  24048.5    22213   110609  4849999  4.58  4.62  4.64
# ...                     ...      ...      ...      ...   ...   ...   ...
# TH:WORK 2019-12-25   1918.2  6005.22  25806.5   441560  13.6  13.3  13.8
#         2019-12-26     1907  6137.69  26514.5   441560  13.9  13.6  14.1
#         2019-12-27   1587.2     6226  22389.9   441560  14.1    14  14.3
#         2019-12-30      159  6181.84   2242.3   441560    14  14.1  14.2
#         2019-12-31      NaN  6181.84      NaN   441560    14   NaN   NaN
#
#                       PL  MACD     PI      RI    DY
# stock   date
# ...

# %%
# See spec of data at
# https://docs.google.com/presentation/d/1rmIMOtRluSUB5iwV5KLMLhDdSXWNv0LlQb9zSZ6kVkg/edit#slide=id.gb5693fedaa_0_19
#
# http://product.datastream.com/navigator/HelpFiles/DatatypeDefinitions/en/3/vo.htm
#
# MV :: Market value in millions of local currency. Calculate from unadjusted share price times number of shares.
# VO :: total number of shares traded displayed in thousands.

facts['MV'] = facts['MV'] * 1000000
facts['VO'] = facts['VO'] * 1000
facts['VA'] = facts['VA'] * 1000

# Convert to numeric
facts['VO'] = pd.to_numeric(facts['VO'])
facts['MV'] = pd.to_numeric(facts['MV'])
facts['VA'] = pd.to_numeric(facts['VA'])
facts['NOSH'] = pd.to_numeric(facts['NOSH'])
facts['P'] = pd.to_numeric(facts['P'])
facts['PO'] = pd.to_numeric(facts['PO'])
facts['PH'] = pd.to_numeric(facts['PH'])
facts['PL'] = pd.to_numeric(facts['PL'])
facts['MACD'] = pd.to_numeric(facts['MACD'])
facts['PI'] = pd.to_numeric(facts['PI'])
facts['RI'] = pd.to_numeric(facts['RI'])
facts['DY'] = pd.to_numeric(facts['DY'])

facts
# Out:
#                             VO            MV           VA       NOSH      P  \
# stock   date
# TH:AAV  2015-01-01         NaN  2.085500e+10          NaN  4849999.0   4.30
#         2015-01-02         NaN  2.085500e+10          NaN  4849999.0   4.30
#         2015-01-05  16567400.0  2.085500e+10   71287900.0  4849999.0   4.30
#         2015-01-06  59230200.0  2.201899e+10  265539000.0  4849999.0   4.54
#         2015-01-07  24048500.0  2.221299e+10  110609100.0  4849999.0   4.58
# ...                        ...           ...          ...        ...    ...
# TH:WORK 2019-12-25   1918200.0  6.005220e+09   25806500.0   441560.0  13.60
#         2019-12-26   1907000.0  6.137690e+09   26514500.0   441560.0  13.90
#         2019-12-27   1587200.0  6.226000e+09   22389900.0   441560.0  14.10
#         2019-12-30    159000.0  6.181840e+09    2242300.0   441560.0  14.00
#         2019-12-31         NaN  6.181840e+09          NaN   441560.0  14.00
#
# ...

# %%
from sqlalchemy import create_engine
engine = create_engine('postgresql://datauser:1234@172.18.0.1:5432/stockdb', echo=False)

# %% [markdown]
# # Load to Table

# %%
facts.to_sql('set100_daily_facts', con=engine, if_exists='replace')

# %% [markdown]
# ## Build Time Dimension Index

# %%
facts.index
# Out:
# MultiIndex([( 'TH:AAV', '2015-01-01'),
#             ( 'TH:AAV', '2015-01-02'),
#             ( 'TH:AAV', '2015-01-05'),
#             ( 'TH:AAV', '2015-01-06'),
#             ( 'TH:AAV', '2015-01-07'),
#             ( 'TH:AAV', '2015-01-08'),
#             ( 'TH:AAV', '2015-01-09'),
#             ( 'TH:AAV', '2015-01-12'),
#             ( 'TH:AAV', '2015-01-13'),
#             ( 'TH:AAV', '2015-01-14'),
#             ...
#             ('TH:WORK', '2019-12-18'),
#             ('TH:WORK', '2019-12-19'),
#             ('TH:WORK', '2019-12-20'),
#             ('TH:WORK', '2019-12-23'),
#             ('TH:WORK', '2019-12-24'),
#             ('TH:WORK', '2019-12-25'),
#             ('TH:WORK', '2019-12-26'),
#             ('TH:WORK', '2019-12-27'),
#             ('TH:WORK', '2019-12-30'),
#             ('TH:WORK', '2019-12-31')],
#            names=['stock', 'date'], length=208640)

# %%
# Swap levels
# https://pandas.pydata.org/pandas-docs/stable/user_guide/advanced.html

by_date = facts.swaplevel(0, 1, axis=0)
by_date.index
# Out:
# MultiIndex([('2015-01-01',  'TH:AAV'),
#             ('2015-01-02',  'TH:AAV'),
#             ('2015-01-05',  'TH:AAV'),
#             ('2015-01-06',  'TH:AAV'),
#             ('2015-01-07',  'TH:AAV'),
#             ('2015-01-08',  'TH:AAV'),
#             ('2015-01-09',  'TH:AAV'),
#             ('2015-01-12',  'TH:AAV'),
#             ('2015-01-13',  'TH:AAV'),
#             ('2015-01-14',  'TH:AAV'),
#             ...
#             ('2019-12-18', 'TH:WORK'),
#             ('2019-12-19', 'TH:WORK'),
#             ('2019-12-20', 'TH:WORK'),
#             ('2019-12-23', 'TH:WORK'),
#             ('2019-12-24', 'TH:WORK'),
#             ('2019-12-25', 'TH:WORK'),
#             ('2019-12-26', 'TH:WORK'),
#             ('2019-12-27', 'TH:WORK'),
#             ('2019-12-30', 'TH:WORK'),
#             ('2019-12-31', 'TH:WORK')],
#            names=['date', 'stock'], length=208640)

# %%
level0 = by_date.index.droplevel(1) # Drop level 1, the stock. https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.MultiIndex.droplevel.html
level0
# Out:
# DatetimeIndex(['2015-01-01', '2015-01-02', '2015-01-05', '2015-01-06',
#                '2015-01-07', '2015-01-08', '2015-01-09', '2015-01-12',
#                '2015-01-13', '2015-01-14',
#                ...
#                '2019-12-18', '2019-12-19', '2019-12-20', '2019-12-23',
#                '2019-12-24', '2019-12-25', '2019-12-26', '2019-12-27',
#                '2019-12-30', '2019-12-31'],
#               dtype='datetime64[ns]', name='date', length=208640, freq=None)

# %%
by_date.index = level0

# %%
by_date['2015-01-06'] # We get all sample for a date, without label
# Out:
#                     VO            MV            VA       NOSH       P      PO  \
# date
# 2015-01-06  59230200.0  2.201899e+10  2.655390e+08  4849999.0    4.54    4.34
# 2015-01-06   4386600.0  7.343538e+11  1.084522e+09  2973094.0  247.00  246.00
# 2015-01-06     85000.0  2.712500e+10  9.177900e+06   250000.0  108.50  107.00
# 2015-01-06   3227500.0  1.717872e+10  5.017700e+07  1067000.0   15.67   15.48
# 2015-01-06   7590100.0  1.086558e+10  2.464770e+07  3332999.0    3.26    3.22
# ...                ...           ...           ...        ...     ...     ...
# 2015-01-06   4024900.0  1.748226e+10  5.215000e+06  1257716.0    1.29    1.30
# 2015-01-06    720500.0  1.198760e+10  5.466800e+06  1567006.0    7.65    7.60
# 2015-01-06  24432200.0  2.891675e+10  6.478410e+07   963892.0    2.66    2.70
# 2015-01-06         NaN           NaN           NaN        NaN     NaN     NaN
# 2015-01-06    907300.0  1.150625e+10  2.769260e+07   266040.0   30.69   30.69
#
# ...

# %%
df2 = facts.swaplevel(0, 1, axis=0)
df2
# Out:
#                             VO            MV           VA       NOSH      P  \
# date       stock
# 2015-01-01 TH:AAV          NaN  2.085500e+10          NaN  4849999.0   4.30
# 2015-01-02 TH:AAV          NaN  2.085500e+10          NaN  4849999.0   4.30
# 2015-01-05 TH:AAV   16567400.0  2.085500e+10   71287900.0  4849999.0   4.30
# 2015-01-06 TH:AAV   59230200.0  2.201899e+10  265539000.0  4849999.0   4.54
# 2015-01-07 TH:AAV   24048500.0  2.221299e+10  110609100.0  4849999.0   4.58
# ...                        ...           ...          ...        ...    ...
# 2019-12-25 TH:WORK   1918200.0  6.005220e+09   25806500.0   441560.0  13.60
# 2019-12-26 TH:WORK   1907000.0  6.137690e+09   26514500.0   441560.0  13.90
# 2019-12-27 TH:WORK   1587200.0  6.226000e+09   22389900.0   441560.0  14.10
# 2019-12-30 TH:WORK    159000.0  6.181840e+09    2242300.0   441560.0  14.00
# 2019-12-31 TH:WORK         NaN  6.181840e+09          NaN   441560.0  14.00
#
# ...

# %%
# Here are the unique dates to build time dimension:
unique_dates = by_date.index.unique()

unique_dates
# Out:
# DatetimeIndex(['2015-01-01', '2015-01-02', '2015-01-05', '2015-01-06',
#                '2015-01-07', '2015-01-08', '2015-01-09', '2015-01-12',
#                '2015-01-13', '2015-01-14',
#                ...
#                '2019-12-18', '2019-12-19', '2019-12-20', '2019-12-23',
#                '2019-12-24', '2019-12-25', '2019-12-26', '2019-12-27',
#                '2019-12-30', '2019-12-31'],
#               dtype='datetime64[ns]', name='date', length=1304, freq=None)

# %%
# Build the time dimension data frame
df_time_dim = pd.DataFrame(unique_dates.values, columns=['dt'], index=unique_dates)
df_time_dim
# Out:
#                    dt
# date
# 2015-01-01 2015-01-01
# 2015-01-02 2015-01-02
# 2015-01-05 2015-01-05
# 2015-01-06 2015-01-06
# 2015-01-07 2015-01-07
# ...               ...
# 2019-12-25 2019-12-25
# 2019-12-26 2019-12-26
# 2019-12-27 2019-12-27
# 2019-12-30 2019-12-30
# 2019-12-31 2019-12-31
#
# [1304 rows x 1 columns]

# %%
# df_time_dim['month'] = 
df_time_dim['month'] = df_time_dim['dt'].apply(lambda x: x.month)
df_time_dim['year'] = df_time_dim['dt'].apply(lambda x: x.year)
df_time_dim['dayofweek'] = df_time_dim['dt'].apply(lambda x: x.dayofweek)
df_time_dim['day_name'] = df_time_dim['dt'].apply(lambda x: x.day_name())
df_time_dim['dayofyear'] = df_time_dim['dt'].apply(lambda x: x.dayofyear)
df_time_dim['daysinmonth'] = df_time_dim['dt'].apply(lambda x: x.daysinmonth)
df_time_dim
# Out:
#                    dt  month  year  dayofweek   day_name  dayofyear  \
# date
# 2015-01-01 2015-01-01      1  2015          3   Thursday          1
# 2015-01-02 2015-01-02      1  2015          4     Friday          2
# 2015-01-05 2015-01-05      1  2015          0     Monday          5
# 2015-01-06 2015-01-06      1  2015          1    Tuesday          6
# 2015-01-07 2015-01-07      1  2015          2  Wednesday          7
# ...               ...    ...   ...        ...        ...        ...
# 2019-12-25 2019-12-25     12  2019          2  Wednesday        359
# 2019-12-26 2019-12-26     12  2019          3   Thursday        360
# 2019-12-27 2019-12-27     12  2019          4     Friday        361
# 2019-12-30 2019-12-30     12  2019          0     Monday        364
# 2019-12-31 2019-12-31     12  2019          1    Tuesday        365
#
#             daysinmonth
# date
# 2015-01-01           31
# 2015-01-02           31
# 2015-01-05           31
# 2015-01-06           31
# ...

# %%
# dayofweek, day_name, dayofyear, daysinmonth

df_time_dim['dt'][0].daysinmonth
# Out:
# 31

# %%
df_time_dim.to_sql('set100_time_dim', con=engine, if_exists='replace')

# %% [markdown]
# # Prepare Company Dimension

# %%
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.read_excel.html
# Get worksheet names

# workbook = pd.read_excel('SET100_Data.xlsm')
# workbook.keys()

os.chdir("/home/jovyan/dataset/Datastream")

sheets = pd.read_excel('SET100_Data.xlsm', sheet_name=[0,'VO','MV','P','MACD']) 
sheets.keys()
# Out:
# odict_keys([0, 'VO', 'MV', 'P', 'MACD'])

# %% [markdown]
# ### Stock Dimension   set100_company_dim

# %%
# List of ticker symbols
symbols = list(sheets[0]['Symbol In SET100 Constituent'].values)

# Data frame
df_tickers = sheets[0][['Symbol In SET100 Constituent', 'Company Name', 'Datastream Mnemonic', 'Remark']]
df_tickers # All 163 stock symbols
# Out:
#     Symbol In SET100 Constituent             Company Name Datastream Mnemonic  \
# 0                            AAV            ASIA AVIATION              Q:AAVP
# 1                         ADVANC       ADVANCED INFO SER.               Q:AIS
# 2                         AEONTS  AE.THANA SINSAP (THAI.)               Q:ATS
# 3                          AMATA                    AMATA              Q:PAKO
# 4                           ANAN       ANANDA DEVELOPMENT              Q:ADTP
# ..                           ...                      ...                 ...
# 158                        VIBHA        VIBHAVADI MEDICAL              Q:VIBH
# 159                          VNG           VANACHAI GROUP              Q:VANA
# 160                          WHA                      WHA              Q:WHAP
# 161                        WHAUP  WHA UTILITIES AND POWER              Q:WHAU
# 162                         WORK  WORKPOINT ENTERTAINMENT              Q:WORK
#
#     Remark
# 0      NaN
# ...

# %%
# The 160 companies
df_companies = df_tickers[df_tickers['Datastream Mnemonic'].notnull()]
df_companies
# Out:
#     Symbol In SET100 Constituent             Company Name Datastream Mnemonic  \
# 0                            AAV            ASIA AVIATION              Q:AAVP
# 1                         ADVANC       ADVANCED INFO SER.               Q:AIS
# 2                         AEONTS  AE.THANA SINSAP (THAI.)               Q:ATS
# 3                          AMATA                    AMATA              Q:PAKO
# 4                           ANAN       ANANDA DEVELOPMENT              Q:ADTP
# ..                           ...                      ...                 ...
# 158                        VIBHA        VIBHAVADI MEDICAL              Q:VIBH
# 159                          VNG           VANACHAI GROUP              Q:VANA
# 160                          WHA                      WHA              Q:WHAP
# 161                        WHAUP  WHA UTILITIES AND POWER              Q:WHAU
# 162                         WORK  WORKPOINT ENTERTAINMENT              Q:WORK
#
#     Remark
# 0      NaN
# ...

# %%
# Check for specific ticker
df_tickers[df_tickers["Symbol In SET100 Constituent"]=="SIM"]
# Out:
#     Symbol In SET100 Constituent        Company Name Datastream Mnemonic  \
# 122                          SIM  SAMART DIGITAL ORS              Q:SIMB
#
#                Remark
# 122  NEW SYMBOL (SDC)

# %%
# The SET100 companies with the sector
sector_lookup = os.path.join(os.environ['EXPERIMENT_HOME'],"""1.0 Data Acquisition/stock_ticker.csv""")
sector_lookup = pd.read_csv(sector_lookup)

set100_companies = df_companies[['Symbol In SET100 Constituent', 'Company Name', 'Datastream Mnemonic']]
set100_companies

# Join
df = set100_companies.merge(sector_lookup, left_on='Symbol In SET100 Constituent', right_on='symbol')
df['localCode'] = 'TH:'+df['symbol']
df
# Out:
#     Symbol In SET100 Constituent             Company Name Datastream Mnemonic  \
# 0                            AAV            ASIA AVIATION              Q:AAVP
# 1                         ADVANC       ADVANCED INFO SER.               Q:AIS
# 2                         AEONTS  AE.THANA SINSAP (THAI.)               Q:ATS
# 3                          AMATA                    AMATA              Q:PAKO
# 4                           ANAN       ANANDA DEVELOPMENT              Q:ADTP
# ..                           ...                      ...                 ...
# 155                        VIBHA        VIBHAVADI MEDICAL              Q:VIBH
# 156                          VNG           VANACHAI GROUP              Q:VANA
# 157                          WHA                      WHA              Q:WHAP
# 158                        WHAUP  WHA UTILITIES AND POWER              Q:WHAU
# 159                         WORK  WORKPOINT ENTERTAINMENT              Q:WORK
#
# ...

# %%
df = df.rename(columns={'Company Name':'company_name',
                   'Datastream Mnemonic': 'datastream_mnemonic',
                   'localCode':'local_code',
                   'name':'stock'
                  })
df = df[['stock','company_name','datastream_mnemonic','local_code','symbol','exchange','industry','sector']]
df.to_sql('set100_company_dim', con=db_engine, if_exists='replace')

# %% [markdown]
# # Select Study Period
#
# We move to SQL. This alevate memory burden of the 'facts' dataframe with multiindex used earlier.

# %%
# facts.loc[]

# %%
# facts['WORKPOINT ENTERTAINMENT','2016-01-01':'2016-01-02']

# Select by date
sql = """SELECT f.* FROM set100_daily_facts f
WHERE f.date BETWEEN '2016-01-01' AND '2016-02-01';"""
df_read = pd.read_sql(sql, engine)
df_read
# Out:
#         stock       date          VO            MV           VA       NOSH  \
# 0      TH:AAV 2016-01-01         NaN  2.546249e+10          NaN  4849999.0
# 1      TH:AAV 2016-01-04   8310700.0  2.497749e+10   42566100.0  4849999.0
# 2      TH:AAV 2016-01-05  39276900.0  2.521999e+10  199397100.0  4849999.0
# 3      TH:AAV 2016-01-06  44470000.0  2.594750e+10  234577400.0  4849999.0
# 4      TH:AAV 2016-01-07  41972900.0  2.667499e+10  228150200.0  4849999.0
# ...       ...        ...         ...           ...          ...        ...
# 3515  TH:WORK 2016-01-26    250600.0  1.669020e+10   10059200.0   417255.0
# 3516  TH:WORK 2016-01-27    134900.0  1.648157e+10    5377400.0   417255.0
# 3517  TH:WORK 2016-01-28    473900.0  1.627294e+10   18703600.0   417255.0
# 3518  TH:WORK 2016-01-29    175300.0  1.606432e+10    6802700.0   417255.0
# 3519  TH:WORK 2016-02-01    161100.0  1.606432e+10    6188400.0   417255.0
#
#           P     PO     PH     PL  MACD     PI      RI    DY
# ...

# %%
vo = df_read['VO'].dropna()
