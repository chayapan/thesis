# %%
import pandas as pd
from sqlalchemy import create_engine
engine = create_engine('postgresql://datauser:1234@172.18.0.1:5432/stockdb', echo=False)

engine.table_names()
# Out:
# ['Price',
#  'DividendYield',
#  'EarningsPerShare',
#  'MarketValue',
#  'TurnoverByValue',
#  'TurnoverByVolume',
#  'UnadjustedPriceOpen',
#  'UnadjustedPrice',
#  'UnadjustedPriceHigh',
#  'UnadjustedPriceLow',
#  'UnadjustedVolume',
#  'PriceToBookValue',
#  'PriceIndex',
#  'TotalReturnIndex',
#  'MarketValueToBook',
#  'NumberOfShares',
#  'TotalAssets',
#  'Company']

# %%
# Test


sql = """SELECT 1"""

engine.execute(sql).fetchall()

"""
select * 
from public."Price";
"""


"""
select dy."AAV" as DY, eps."AAV" as EPS
FROM
public."DividendYield" dy
join 
public."EarningsPerShare" eps 
on 
dy."Date" = eps."Date"
;

"""
# Out:
# [(1,)]

# %% [markdown]
# # View 1: By Date

# %%
sql = """
select dy."Date", dy."AAV" as DY, eps."AAV" as EPS
FROM
public."DividendYield" dy
join 
public."EarningsPerShare" eps 
on 
dy."Date" = eps."Date"
;
"""

engine.execute(sql).fetchall()
# Out:
# [(datetime.datetime(2014, 1, 1, 0, 0), 3.66, 3.66),
#  (datetime.datetime(2014, 1, 2, 0, 0), 3.44, 3.44),
#  (datetime.datetime(2014, 1, 3, 0, 0), 3.42, 3.42),
#  (datetime.datetime(2014, 1, 6, 0, 0), 3.54, 3.54),
#  (datetime.datetime(2014, 1, 7, 0, 0), 3.72, 3.72),
#  (datetime.datetime(2014, 1, 8, 0, 0), 3.64, 3.64),
#  (datetime.datetime(2014, 1, 9, 0, 0), 3.58, 3.58),
#  (datetime.datetime(2014, 1, 10, 0, 0), 3.54, 3.54),
#  (datetime.datetime(2014, 1, 13, 0, 0), 3.54, 3.54),
#  (datetime.datetime(2014, 1, 14, 0, 0), 3.76, 3.76),
#  (datetime.datetime(2014, 1, 15, 0, 0), 3.82, 3.82),
#  (datetime.datetime(2014, 1, 16, 0, 0), 4.08, 4.08),
#  (datetime.datetime(2014, 1, 17, 0, 0), 3.88, 3.88),
#  (datetime.datetime(2014, 1, 20, 0, 0), 3.8, 3.8),
#  (datetime.datetime(2014, 1, 21, 0, 0), 3.82, 3.82),
#  (datetime.datetime(2014, 1, 22, 0, 0), 3.7, 3.7),
#  (datetime.datetime(2014, 1, 23, 0, 0), 3.72, 3.72),
#  (datetime.datetime(2014, 1, 24, 0, 0), 3.74, 3.74),
# ...

# %% [markdown]
# ## View by Stock
#
#
# Use subquery
# https://www.postgresqltutorial.com/postgresql-subquery/

# %%
sql = """
select uvo."Date", dy."AAV" as DY, eps."AAV" as EPS
FROM
public."UnadjustedVolume" uvo
;
"""

engine.execute(sql).fetchall()
