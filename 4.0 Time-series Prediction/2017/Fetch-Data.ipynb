# %%
# Update_10 January 1, 2017 - June 30, 2017 (Published on December 16, 2016)

# %%
SET100_Update_10 = """AAV
ADVANC
AMATA
AOT
AP
BA
BANPU
BBL
BCH
BCP
BDMS
BEAUTY
BEC
BEM
BH
BIG
BLA
BLAND
BTS
CBG
CENTEL
CHG
CK
CKP
COM7
CPALL
CPF
CPN
DELTA
DTAC
EGCO
EPG
GLOBAL
GLOW
GPSC
GUNKUL
HANA
HMPRO
ICHI
IFEC
INTUCH
IRPC
ITD
IVL
KAMART
KBANK
KCE
KKP
KTB
KTC
LH
LHBANK
LPN
MAJOR
MINT
MTLS
PLANB
PSH
PTG
PTT
PTTEP
PTTGC
QH
ROBINS
RS
S
SAMART
SAWAD
SCB
SCC
SCN
SGP
SIRI
SPALI
SPCG
SPRC
STEC
STPI
SUPER
TASCO
TCAP
THAI
THANI
THCOM
TISCO
TKN
TMB
TOP
TPIPL
TRUE
TTA
TTCL
TTW
TU
TVO
UNIQ
VGI
VIBHA
VNG
WHA""".split()

# %%
SET100_Update_10
# Out:
# ['AAV',
#  'ADVANC',
#  'AMATA',
#  'AOT',
#  'AP',
#  'BA',
#  'BANPU',
#  'BBL',
#  'BCH',
#  'BCP',
#  'BDMS',
#  'BEAUTY',
#  'BEC',
#  'BEM',
#  'BH',
#  'BIG',
#  'BLA',
#  'BLAND',
#  'BTS',
#  'CBG',
#  'CENTEL',
#  'CHG',
#  'CK',
#  'CKP',
#  'COM7',
#  'CPALL',
#  'CPF',
#  'CPN',
#  'DELTA',
#  'DTAC',
#  'EGCO',
#  'EPG',
#  'GLOBAL',
#  'GLOW',
#  'GPSC',
#  'GUNKUL',
#  'HANA',
#  'HMPRO',
#  'ICHI',
#  'IFEC',
#  'INTUCH',
#  'IRPC',
#  'ITD',
#  'IVL',
#  'KAMART',
#  'KBANK',
#  'KCE',
#  'KKP',
#  'KTB',
#  'KTC',
#  'LH',
#  'LHBANK',
#  'LPN',
#  'MAJOR',
#  'MINT',
#  'MTLS',
#  'PLANB',
#  'PSH',
#  'PTG',
#  'PTT',
#  'PTTEP',
#  'PTTGC',
#  'QH',
#  'ROBINS',
#  'RS',
#  'S',
#  'SAMART',
#  'SAWAD',
#  'SCB',
#  'SCC',
#  'SCN',
#  'SGP',
#  'SIRI',
#  'SPALI',
#  'SPCG',
#  'SPRC',
#  'STEC',
#  'STPI',
#  'SUPER',
#  'TASCO',
#  'TCAP',
#  'THAI',
#  'THANI',
#  'THCOM',
#  'TISCO',
#  'TKN',
#  'TMB',
#  'TOP',
#  'TPIPL',
#  'TRUE',
#  'TTA',
#  'TTCL',
# ...

# %%
import pandas as pd
import pandas_datareader as pdr
import datetime as dt
import os, os.path
start = dt.datetime(2017,1,1)
end = dt.datetime(2017,12,30)

for s in SET100_Update_10:
    print(s)
    try:
        data = pdr.get_data_yahoo('%s.BK' % s, start=start)
        outfile = "data/%s.csv" % s
        data.to_csv(outfile)
    except Exception as e:
        print("Error: %s %s" % (s, str(e)))
# Out:
# AAV
# ADVANC
# AMATA
# AOT
# AP
# BA
# BANPU
# BBL
# BCH
# BCP
# BDMS
# BEAUTY
# BEC
# BEM
# BH
# BIG
# BLA
# BLAND
# BTS
# CBG
# CENTEL
# CHG
# CK
# CKP
# COM7
# CPALL
# CPF
# CPN
# DELTA
# DTAC
# EGCO
# EPG
# GLOBAL
# GLOW
# Error: GLOW No data fetched for symbol GLOW.BK using YahooDailyReader
# GPSC
# GUNKUL
# HANA
# HMPRO
# ICHI
# IFEC
# Error: IFEC No data fetched for symbol IFEC.BK using YahooDailyReader
# INTUCH
# IRPC
# ITD
# IVL
# KAMART
# KBANK
# KCE
# KKP
# KTB
# KTC
# LH
# LHBANK
# Error: LHBANK 'Date'
# LPN
# MAJOR
# MINT
# MTLS
# Error: MTLS 'Date'
# PLANB
# PSH
# PTG
# PTT
# PTTEP
# PTTGC
# QH
# ROBINS
# RS
# S
# SAMART
# SAWAD
# SCB
# SCC
# SCN
# SGP
# SIRI
# SPALI
# SPCG
# SPRC
# STEC
# STPI
# SUPER
# TASCO
# TCAP
# THAI
# THANI
# THCOM
# TISCO
# TKN
# TMB
# TOP
# TPIPL
# TRUE
# TTA
# TTCL
# TTW
# TU
# TVO
# UNIQ
# VGI
# VIBHA
# VNG
# WHA

# %%
# July 1, 2017 - Dec 31, 2017 (Published on June 16, 2017)
# Update_11

# %%
SET100_Update_11 = """AAV
ADVANC
AMATA
ANAN
AOT
AP
BA
BANPU
BBL
BCH
BCP
BCPG
BDMS
BEAUTY
BEC
BEM
BH
BIG
BJC
BLA
BLAND
BPP
BTS
CBG
CENTEL
CHG
CK
CKP
COM7
CPALL
CPF
CPN
DELTA
DTAC
EA
EGCO
EPG
GFPT
GLOBAL
GLOW
GPSC
GUNKUL
HMPRO
INTUCH
IRPC
ITD
IVL
KBANK
KCE
KKP
KTB
KTC
LH
LHBANK
LPN
MAJOR
MALEE
MEGA
MINT
MONO
MTLS
PLANB
PSH
PTG
PTL
PTT
PTTEP
PTTGC
QH
RATCH
ROBINS
S
SAWAD
SCB
SCC
SCCC
SIRI
SCCC
SPALI
SPRC
STEC
STPI
SUPER
TASCO
TCAP
THANI
THCOM
TISCO
TKN
TMB
TOP
TPIPL
TRUE
TTA
TU
TVO
UNIQ
VGI
WHA
WORK""".split()

# %%
start = dt.datetime(2017,6,30)
end = dt.datetime(2017,12,31)

for s in SET100_Update_11:
    print(s)
    try:
        data = pdr.get_data_yahoo('%s.BK' % s, start=start)
        outfile = "data/%s.csv" % s
        data.to_csv(outfile)
    except Exception as e:
        print("Error: %s %s" % (s, str(e)))
