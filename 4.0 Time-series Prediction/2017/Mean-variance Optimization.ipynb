# %% [markdown]
# Rewrite of: Method1_10-stock-DCP.pdf

# %%
# !pip install cvxpy

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from cvxpy import *

# %%
# Use prediction results for MVO

# %%
df = pd.read_csv("2017predict.csv")
df = df.set_index('Date')
df
# Out:
#                  AAV      ADVANC      AMATA        AOT        AP         BA  \
# Date
# 2017-02-16  6.232253  175.794618  15.655079  39.967695  7.390478  21.105266
# 2017-02-17  6.269532  176.585478  15.749472  40.184469  7.435996  21.059504
# 2017-02-20  6.214249  173.871956  16.030738  40.404344  7.436325  20.913482
# 2017-02-21  6.203613  170.550548  16.218602  39.701591  7.380649  20.284422
# 2017-02-22  6.140224  172.631922  16.101116  40.075578  7.323652  20.352504
# ...              ...         ...        ...        ...       ...        ...
# 2017-12-22  6.246940  187.746678  25.271278  63.926290  9.112736  17.376086
# 2017-12-25  6.124235  189.170365  25.433263  64.812453  9.033019  17.193339
# 2017-12-26  6.118868  188.906405  25.498287  65.675921  9.044854  17.014700
# 2017-12-27  6.114092  189.178240  25.417699  65.393481  9.161493  16.839135
# 2017-12-28  6.054065  191.073714  25.177462  65.250882  9.035506  17.058445
#
#                 BANPU         BBL        BCH        BCP  ...        TTA  \
# Date                                                     ...
# 2017-02-16  19.961343  183.106289  14.170926  35.086826  ...  10.010886
# 2017-02-17  19.650504  183.654080  14.317634  35.115265  ...  10.141241
# 2017-02-20  19.723706  184.160007  14.214027  33.433528  ...  10.627682
# 2017-02-21  19.376665  179.894086  14.067695  33.115483  ...  10.300507
# 2017-02-22  19.349912  180.141131  13.972480  33.432353  ...  10.362379
# ...               ...         ...        ...        ...  ...        ...
# 2017-12-22  20.633239  206.819206  15.694541  39.419026  ...   8.652474
# 2017-12-25  20.170234  208.210044  15.695932  39.711411  ...   8.490315
# 2017-12-26  20.205469  205.640847  15.604218  40.217179  ...   8.741919
# 2017-12-27  19.876407  204.531494  15.606103  40.033609  ...   8.658802
# 2017-12-28  20.821058  202.070207  15.790583  39.278120  ...   8.557393
#
#                  TTCL        TTW         TU        TVO       UNIQ       VGI  \
# Date
# 2017-02-16  19.395470  10.760391  19.544756  41.250923  18.125492  5.156282
# 2017-02-17  19.688548  10.762650  19.316085  41.379895  18.285887  5.140087
# 2017-02-20  19.404421  10.761691  19.428784  40.844053  18.133857  5.175092
# 2017-02-21  18.902498  10.842920  19.196699  40.964345  17.984319  5.092206
# 2017-02-22  18.856771  10.926093  19.316668  41.120557  18.168752  5.128688
# ...               ...        ...        ...        ...        ...       ...
# 2017-12-22  17.015545  12.525255  19.333715  29.766227  15.257064  6.253031
# 2017-12-25  16.855424  12.587594  19.477752  29.936169  15.088116  6.303193
# 2017-12-26  16.579952  12.521848  19.358610  29.763738  15.005981  6.432073
# 2017-12-27  16.830748  12.454393  19.505247  29.726266  15.351100  6.523000
# 2017-12-28  16.683041  12.454537  19.862285  29.704540  15.050749  6.581492
#
#                VIBHA        VNG       WHA
# Date
# 2017-02-16  2.891833  15.378970  3.270242
# 2017-02-17  2.893892  15.541334  3.228477
# 2017-02-20  2.867692  15.444618  3.184238
# 2017-02-21  2.835631  15.162015  3.040150
# 2017-02-22  2.851302  15.033087  3.030796
# ...              ...        ...       ...
# 2017-12-22  2.519383  10.641420  3.906027
# 2017-12-25  2.513411  10.610799  3.966927
# 2017-12-26  2.538852  10.354448  3.983628
# 2017-12-27  2.515135  10.329047  3.964254
# 2017-12-28  2.489732  10.632386  3.883974
#
# [212 rows x 88 columns]

# %%
df_return = df.pct_change() * 100 # Use log function instead.
df_return = df_return.dropna()
df_return
# Out:
#                  AAV    ADVANC     AMATA       AOT        AP        BA  \
# Date
# 2017-02-17  0.598154  0.449877  0.602955  0.542373  0.615895 -0.216831
# 2017-02-20 -0.881770 -1.536662  1.785878  0.547165  0.004430 -0.693375
# 2017-02-21 -0.171152 -1.910261  1.171895 -1.739301 -0.748710 -3.007919
# 2017-02-22 -1.021803  1.220385 -0.724392  0.941995 -0.772249  0.335640
# 2017-02-23  0.700077  0.007862  0.896733 -1.573557  1.449647 -1.064656
# ...              ...       ...       ...       ...       ...       ...
# 2017-12-22  1.114001  0.445246  0.643649  0.583401  0.856044 -0.001506
# 2017-12-25 -1.964243  0.758302  0.640982  1.386225 -0.874791 -1.051715
# 2017-12-26 -0.087632 -0.139535  0.255668  1.332256  0.131019 -1.039005
# 2017-12-27 -0.078055  0.143899 -0.316055 -0.430051  1.289565 -1.031844
# 2017-12-28 -0.981782  1.001952 -0.945155 -0.218063 -1.375176  1.302383
#
#                BANPU       BBL       BCH       BCP  ...       TTA      TTCL  \
# Date                                                ...
# 2017-02-17 -1.557205  0.299166  1.035276  0.081053  ...  1.302129  1.511064
# 2017-02-20  0.372521  0.275478 -0.723630 -4.789193  ...  4.796662 -1.443109
# 2017-02-21 -1.759511 -2.316421 -1.029490 -0.951274  ... -3.078512 -2.586644
# 2017-02-22 -0.138069  0.137328 -0.676836  0.956864  ...  0.600667 -0.241907
# 2017-02-23  0.281176 -0.253250  0.372263  2.937042  ... -2.028215 -2.544236
# ...              ...       ...       ...       ...  ...       ...       ...
# 2017-12-22  0.511389  0.166435  0.070655  1.226342  ... -2.970337 -0.461257
# 2017-12-25 -2.243977  0.672490  0.008864  0.741736  ... -1.874138 -0.941028
# 2017-12-26  0.174686 -1.233945 -0.584316  1.273609  ...  2.963426 -1.634322
# 2017-12-27 -1.628576 -0.539461  0.012076 -0.456447  ... -0.950792  1.512647
# 2017-12-28  4.752625 -1.203378  1.182102 -1.887138  ... -1.171160 -0.877603
#
#                  TTW        TU       TVO      UNIQ       VGI     VIBHA  \
# Date
# 2017-02-17  0.020990 -1.169987  0.312653  0.884919 -0.314087  0.071225
# 2017-02-20 -0.008910  0.583449 -1.294933 -0.831409  0.681013 -0.905375
# 2017-02-21  0.754803 -1.194542  0.294516 -0.824635 -1.601633 -1.117985
# 2017-02-22  0.767068  0.624946  0.381334  1.025522  0.716436  0.552616
# 2017-02-23  0.102659 -0.262086 -1.780605 -2.600669 -0.200787  0.673133
# ...              ...       ...       ...       ...       ...       ...
# 2017-12-22 -0.015423  0.173617 -0.521270 -0.525101  0.087838  0.903067
# 2017-12-25  0.497701  0.745009  0.570920 -1.107342  0.802202 -0.237010
# 2017-12-26 -0.522308 -0.611683 -0.575995 -0.544370  2.044691  1.012201
# 2017-12-27 -0.538692  0.757472 -0.125898  2.299877  1.413645 -0.934177
# 2017-12-28  0.001152  1.830474 -0.073086 -1.956548  0.896709 -1.010015
#
#                  VNG       WHA
# Date
# 2017-02-17  1.055753 -1.277140
# 2017-02-20 -0.622313 -1.370271
# 2017-02-21 -1.829783 -4.525038
# 2017-02-22 -0.850341 -0.307670
# 2017-02-23 -0.258514  3.459116
# ...              ...       ...
# 2017-12-22  1.203919 -0.929172
# 2017-12-25 -0.287748  1.559129
# 2017-12-26 -2.415944  0.421005
# 2017-12-27 -0.245313 -0.486328
# 2017-12-28  2.936755 -2.025114
#
# [211 rows x 88 columns]

# %%
df_return.cov() # Covariance matrix from whole 2017 prediction. Dont use this. 
# Need to develop walk-forward
# Out:
#              AAV    ADVANC     AMATA       AOT        AP        BA     BANPU  \
# AAV     2.020733  0.298274  0.186766  0.196743  0.268019  0.109824  0.252544
# ADVANC  0.298274  1.680827  0.300611  0.268681  0.119868 -0.002666  0.175833
# AMATA   0.186766  0.300611  2.081555  0.039407  0.241466 -0.047221  0.356812
# AOT     0.196743  0.268681  0.039407  0.751626  0.012320  0.144697  0.022933
# AP      0.268019  0.119868  0.241466  0.012320  1.592920 -0.184687  0.120219
# ...          ...       ...       ...       ...       ...       ...       ...
# UNIQ    0.370873  0.368102  0.254725 -0.011689  0.456118  0.026745  0.716440
# VGI    -0.063360  0.169402  0.346092  0.012312  0.168522  0.121428  0.600355
# VIBHA   0.344636 -0.010242  0.507509  0.058719  0.087046  0.371648  0.216251
# VNG     0.114919  0.208888  0.123146 -0.035826 -0.091127  0.223886  0.523403
# WHA     0.212200  0.345614  1.114337 -0.010379  0.431493  0.111353  0.838232
#
#              BBL       BCH       BCP  ...       TTA      TTCL       TTW  \
# AAV     0.026222  0.054251  0.034401  ...  0.096241  0.266418  0.043297
# ADVANC  0.226374  0.111721  0.261108  ...  0.237599  0.122424 -0.152954
# AMATA   0.267151  0.231493 -0.196494  ...  0.127238  0.437841 -0.064180
# AOT     0.084241  0.000490  0.206192  ...  0.190162 -0.022980 -0.040016
# AP      0.065456  0.241693 -0.117708  ...  0.202748 -0.022661  0.181921
# ...          ...       ...       ...  ...       ...       ...       ...
# UNIQ    0.378850  0.115146  0.228414  ...  1.116421  1.448058  0.113663
# VGI    -0.058862  0.222819  0.351390  ...  0.066843  0.888291 -0.028519
# VIBHA   0.069437  0.288537  0.135317  ... -0.260100  0.791400 -0.148705
# VNG     0.048859  0.193394  0.240755  ...  0.193268  0.537980 -0.171943
# WHA     0.380391  0.288728  0.097210  ...  0.204649  1.518943 -0.094639
#
#               TU       TVO      UNIQ       VGI     VIBHA       VNG       WHA
# AAV     0.331579 -0.018885  0.370873 -0.063360  0.344636  0.114919  0.212200
# ADVANC  0.232129  0.113489  0.368102  0.169402 -0.010242  0.208888  0.345614
# AMATA   0.370581  0.103306  0.254725  0.346092  0.507509  0.123146  1.114337
# AOT     0.079320  0.056428 -0.011689  0.012312  0.058719 -0.035826 -0.010379
# AP      0.008903  0.169146  0.456118  0.168522  0.087046 -0.091127  0.431493
# ...          ...       ...       ...       ...       ...       ...       ...
# UNIQ    0.573963  0.468724  3.836553  0.485247  0.196001  0.494812  0.241230
# VGI    -0.035535  0.175292  0.485247  3.774936  0.312342  0.260377  0.209516
# VIBHA   0.066861 -0.073523  0.196001  0.312342  1.520413  0.175958  0.640996
# VNG     0.098724  0.246859  0.494812  0.260377  0.175958  2.855402  0.046071
# WHA    -0.012296 -0.065194  0.241230  0.209516  0.640996  0.046071  4.550924
#
# [88 rows x 88 columns]

# %%
mean_returns = df_return.mean()
mean_returns
# Out:
# AAV      -0.003664
# ADVANC    0.047887
# AMATA     0.235671
# AOT       0.236315
# AP        0.103217
#             ...
# UNIQ     -0.069069
# VGI       0.134575
# VIBHA    -0.063409
# VNG      -0.160770
# WHA       0.104126
# Length: 88, dtype: float64

# %%
cov_matrix = df_return.cov()
risk_free_rate = 0.0178 # Changeme
cov_matrix
# Out:
#              AAV    ADVANC     AMATA       AOT        AP        BA     BANPU  \
# AAV     2.020733  0.298274  0.186766  0.196743  0.268019  0.109824  0.252544
# ADVANC  0.298274  1.680827  0.300611  0.268681  0.119868 -0.002666  0.175833
# AMATA   0.186766  0.300611  2.081555  0.039407  0.241466 -0.047221  0.356812
# AOT     0.196743  0.268681  0.039407  0.751626  0.012320  0.144697  0.022933
# AP      0.268019  0.119868  0.241466  0.012320  1.592920 -0.184687  0.120219
# ...          ...       ...       ...       ...       ...       ...       ...
# UNIQ    0.370873  0.368102  0.254725 -0.011689  0.456118  0.026745  0.716440
# VGI    -0.063360  0.169402  0.346092  0.012312  0.168522  0.121428  0.600355
# VIBHA   0.344636 -0.010242  0.507509  0.058719  0.087046  0.371648  0.216251
# VNG     0.114919  0.208888  0.123146 -0.035826 -0.091127  0.223886  0.523403
# WHA     0.212200  0.345614  1.114337 -0.010379  0.431493  0.111353  0.838232
#
#              BBL       BCH       BCP  ...       TTA      TTCL       TTW  \
# AAV     0.026222  0.054251  0.034401  ...  0.096241  0.266418  0.043297
# ADVANC  0.226374  0.111721  0.261108  ...  0.237599  0.122424 -0.152954
# AMATA   0.267151  0.231493 -0.196494  ...  0.127238  0.437841 -0.064180
# AOT     0.084241  0.000490  0.206192  ...  0.190162 -0.022980 -0.040016
# AP      0.065456  0.241693 -0.117708  ...  0.202748 -0.022661  0.181921
# ...          ...       ...       ...  ...       ...       ...       ...
# UNIQ    0.378850  0.115146  0.228414  ...  1.116421  1.448058  0.113663
# VGI    -0.058862  0.222819  0.351390  ...  0.066843  0.888291 -0.028519
# VIBHA   0.069437  0.288537  0.135317  ... -0.260100  0.791400 -0.148705
# VNG     0.048859  0.193394  0.240755  ...  0.193268  0.537980 -0.171943
# WHA     0.380391  0.288728  0.097210  ...  0.204649  1.518943 -0.094639
#
#               TU       TVO      UNIQ       VGI     VIBHA       VNG       WHA
# AAV     0.331579 -0.018885  0.370873 -0.063360  0.344636  0.114919  0.212200
# ADVANC  0.232129  0.113489  0.368102  0.169402 -0.010242  0.208888  0.345614
# AMATA   0.370581  0.103306  0.254725  0.346092  0.507509  0.123146  1.114337
# AOT     0.079320  0.056428 -0.011689  0.012312  0.058719 -0.035826 -0.010379
# AP      0.008903  0.169146  0.456118  0.168522  0.087046 -0.091127  0.431493
# ...          ...       ...       ...       ...       ...       ...       ...
# UNIQ    0.573963  0.468724  3.836553  0.485247  0.196001  0.494812  0.241230
# VGI    -0.035535  0.175292  0.485247  3.774936  0.312342  0.260377  0.209516
# VIBHA   0.066861 -0.073523  0.196001  0.312342  1.520413  0.175958  0.640996
# VNG     0.098724  0.246859  0.494812  0.260377  0.175958  2.855402  0.046071
# WHA    -0.012296 -0.065194  0.241230  0.209516  0.640996  0.046071  4.550924
#
# [88 rows x 88 columns]

# %%
returns = df_return.dropna() # The first data is nan. # Convert daily return data frame to a numpy matrix
return_data = returns.as_matrix().T 
return_data
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:2: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
# array([[ 0.59815389, -0.88177001, -0.17115228, ..., -0.0876324 ,
#         -0.07805486, -0.98178189],
#        [ 0.44987743, -1.53666215, -1.91026073, ..., -0.13953539,
#          0.1438991 ,  1.00195167],
#        [ 0.60295455,  1.78587829,  1.1718948 , ...,  0.25566791,
#         -0.31605512, -0.94515523],
#        ...,
#        [ 0.07122499, -0.90537487, -1.11798482, ...,  1.01220111,
#         -0.93417689, -1.01001546],
#        [ 1.05575258, -0.6223133 , -1.82978296, ..., -2.41594398,
#         -0.24531326,  2.9367546 ],
#        [-1.27713997, -1.37027093, -4.52503752, ...,  0.42100475,
#         -0.48632807, -2.02511387]])

# %%
#  Plot daily return

plt.figure(figsize=(14, 7))
for c in df_return.columns.values:
    plt.plot(df_return.index, df_return[c], lw=3, alpha=0.8,label=c) 
    plt.legend(loc='upper right', fontsize=12)
    plt.ylabel('daily returns')

# %%
# Mean return

r = np.mean(return_data, axis=1)
r
# Out:
# array([-0.00366427,  0.04788719,  0.23567092,  0.2363151 ,  0.10321696,
#        -0.0867471 ,  0.0430784 ,  0.05240757,  0.0567068 ,  0.0647097 ,
#         0.0190378 ,  0.32404977, -0.19068335,  0.04033208,  0.02569338,
#        -0.26722389, -0.1633976 ,  0.01556614,  0.05021114,  0.21430226,
#        -0.12271217, -0.02266244,  0.10941456,  0.13725991, -0.07083816,
#         0.21518509, -0.10134256,  0.03940158, -0.07452159,  0.02932721,
#        -0.06494038,  0.04541036,  0.14665872, -0.00865132,  0.0055351 ,
#         0.1444381 , -0.11743037,  0.17128493, -0.08404489,  0.08934697,
#        -0.13976407,  0.1265806 , -0.00593856,  0.14280534,  0.03075028,
#         0.04540104, -0.0365403 ,  0.13318118,  0.00617571, -0.11369829,
#         0.05362056,  0.0645551 ,  0.10266187, -0.12725059, -0.06681162,
#         0.21856121, -0.00925779, -0.03714779, -0.17436589,  0.29478396,
#         0.02390973, -0.01354051, -0.00368463,  0.12849562, -0.05172675,
#        -0.19519002, -0.00471426, -0.04334993,  0.06839152, -0.08723687,
#         0.3072421 , -0.16325799,  0.14525194, -0.08106454,  0.09737104,
#         0.14411566, -0.07009632,  0.13673619, -0.04587553, -0.00472992,
#         0.07421125,  0.01842763, -0.14881208, -0.06906905,  0.13457454,
#        -0.06340905, -0.16076996,  0.10412578])

# %%
# Covariance matrix

C = np.asmatrix(np.cov(return_data))
C
# Out:
# /opt/conda/lib/python3.7/site-packages/numpy/matrixlib/defmatrix.py:71: PendingDeprecationWarning: the matrix subclass is not the recommended way to represent matrices or deal with linear algebra (see https://docs.scipy.org/doc/numpy/user/numpy-for-matlab-users.html). Please adjust your code to use regular ndarray.
#   return matrix(data, dtype=dtype, copy=False)
# matrix([[ 2.02073315,  0.29827387,  0.18676622, ...,  0.34463554,
#           0.1149191 ,  0.21219981],
#         [ 0.29827387,  1.68082676,  0.30061142, ..., -0.01024185,
#           0.20888844,  0.34561421],
#         [ 0.18676622,  0.30061142,  2.08155523, ...,  0.50750911,
#           0.12314595,  1.11433697],
#         ...,
#         [ 0.34463554, -0.01024185,  0.50750911, ...,  1.52041334,
#           0.17595788,  0.64099627],
#         [ 0.1149191 ,  0.20888844,  0.12314595, ...,  0.17595788,
#           2.85540243,  0.04607113],
#         [ 0.21219981,  0.34561421,  1.11433697, ...,  0.64099627,
#           0.04607113,  4.55092362]])

# %%
symbols = df_return.columns
symbols
# Out:
# Index(['AAV', 'ADVANC', 'AMATA', 'AOT', 'AP', 'BA', 'BANPU', 'BBL', 'BCH',
#        'BCP', 'BDMS', 'BEAUTY', 'BEC', 'BEM', 'BH', 'BIG', 'BLA', 'BTS', 'CBG',
#        'CENTEL', 'CHG', 'CK', 'CKP', 'CPALL', 'CPF', 'CPN', 'DELTA', 'EGCO',
#        'EPG', 'GLOBAL', 'GUNKUL', 'HANA', 'HMPRO', 'ICHI', 'INTUCH', 'IRPC',
#        'ITD', 'IVL', 'KAMART', 'KBANK', 'KCE', 'KKP', 'KTB', 'KTC', 'LH',
#        'LPN', 'MAJOR', 'MINT', 'PLANB', 'PTG', 'PTT', 'PTTEP', 'PTTGC', 'S',
#        'SAMART', 'SAWAD', 'SCB', 'SCC', 'SCN', 'SGP', 'SIRI', 'SPALI', 'SPCG',
#        'SPRC', 'STEC', 'STPI', 'SUPER', 'TASCO', 'TCAP', 'THAI', 'THANI',
#        'THCOM', 'TISCO', 'TKN', 'TMB', 'TOP', 'TPIPL', 'TRUE', 'TTA', 'TTCL',
#        'TTW', 'TU', 'TVO', 'UNIQ', 'VGI', 'VIBHA', 'VNG', 'WHA'],
#       dtype='object')

# %%
# Print expected returns and risk
for j in range(len(symbols)):
    print ('%s: Exp ret = %f, Risk = %f' %(symbols[j],r[j], C[j,j]**0.5))
# Out:
# AAV: Exp ret = -0.003664, Risk = 1.421525
# ADVANC: Exp ret = 0.047887, Risk = 1.296467
# AMATA: Exp ret = 0.235671, Risk = 1.442760
# AOT: Exp ret = 0.236315, Risk = 0.866964
# AP: Exp ret = 0.103217, Risk = 1.262109
# BA: Exp ret = -0.086747, Risk = 1.701608
# BANPU: Exp ret = 0.043078, Risk = 2.155035
# BBL: Exp ret = 0.052408, Risk = 1.068144
# BCH: Exp ret = 0.056707, Risk = 1.044843
# BCP: Exp ret = 0.064710, Risk = 1.503451
# BDMS: Exp ret = 0.019038, Risk = 1.241901
# BEAUTY: Exp ret = 0.324050, Risk = 1.099285
# BEC: Exp ret = -0.190683, Risk = 3.668762
# BEM: Exp ret = 0.040332, Risk = 1.228567
# BH: Exp ret = 0.025693, Risk = 1.404268
# BIG: Exp ret = -0.267224, Risk = 0.978772
# BLA: Exp ret = -0.163398, Risk = 2.038527
# BTS: Exp ret = 0.015566, Risk = 1.192519
# CBG: Exp ret = 0.050211, Risk = 1.586623
# CENTEL: Exp ret = 0.214302, Risk = 1.585427
# CHG: Exp ret = -0.122712, Risk = 2.176667
# CK: Exp ret = -0.022662, Risk = 1.460875
# CKP: Exp ret = 0.109415, Risk = 1.494266
# CPALL: Exp ret = 0.137260, Risk = 0.913152
# CPF: Exp ret = -0.070838, Risk = 1.585600
# CPN: Exp ret = 0.215185, Risk = 1.025117
# DELTA: Exp ret = -0.101343, Risk = 1.520708
# EGCO: Exp ret = 0.039402, Risk = 0.754467
# EPG: Exp ret = -0.074522, Risk = 1.550569
# GLOBAL: Exp ret = 0.029327, Risk = 1.303078
# GUNKUL: Exp ret = -0.064940, Risk = 1.958985
# HANA: Exp ret = 0.045410, Risk = 1.710654
# HMPRO: Exp ret = 0.146659, Risk = 1.059539
# ICHI: Exp ret = -0.008651, Risk = 3.637181
# INTUCH: Exp ret = 0.005535, Risk = 1.246322
# IRPC: Exp ret = 0.144438, Risk = 1.234366
# ITD: Exp ret = -0.117430, Risk = 3.087179
# IVL: Exp ret = 0.171285, Risk = 1.335658
# KAMART: Exp ret = -0.084045, Risk = 1.339029
# KBANK: Exp ret = 0.089347, Risk = 1.245954
# KCE: Exp ret = -0.139764, Risk = 0.966216
# KKP: Exp ret = 0.126581, Risk = 0.972489
# KTB: Exp ret = -0.005939, Risk = 1.277102
# KTC: Exp ret = 0.142805, Risk = 1.433111
# LH: Exp ret = 0.030750, Risk = 1.376071
# LPN: Exp ret = 0.045401, Risk = 2.431989
# MAJOR: Exp ret = -0.036540, Risk = 1.470979
# MINT: Exp ret = 0.133181, Risk = 1.535667
# PLANB: Exp ret = 0.006176, Risk = 1.864530
# PTG: Exp ret = -0.113698, Risk = 1.662840
# PTT: Exp ret = 0.053621, Risk = 1.222388
# PTTEP: Exp ret = 0.064555, Risk = 1.975871
# PTTGC: Exp ret = 0.102662, Risk = 1.094272
# S: Exp ret = -0.127251, Risk = 3.159288
# SAMART: Exp ret = -0.066812, Risk = 3.160001
# SAWAD: Exp ret = 0.218561, Risk = 1.338511
# SCB: Exp ret = -0.009258, Risk = 1.331357
# SCC: Exp ret = -0.037148, Risk = 1.029930
# SCN: Exp ret = -0.174366, Risk = 3.528580
# SGP: Exp ret = 0.294784, Risk = 2.017144
# SIRI: Exp ret = 0.023910, Risk = 1.745538
# SPALI: Exp ret = -0.013541, Risk = 1.324435
# SPCG: Exp ret = -0.003685, Risk = 1.479536
# SPRC: Exp ret = 0.128496, Risk = 1.521373
# STEC: Exp ret = -0.051727, Risk = 1.641452
# STPI: Exp ret = -0.195190, Risk = 3.899184
# SUPER: Exp ret = -0.004714, Risk = 3.502499
# TASCO: Exp ret = -0.043350, Risk = 1.528876
# TCAP: Exp ret = 0.068392, Risk = 0.878301
# THAI: Exp ret = -0.087237, Risk = 2.179178
# THANI: Exp ret = 0.307242, Risk = 1.504809
# THCOM: Exp ret = -0.163258, Risk = 3.483516
# TISCO: Exp ret = 0.145252, Risk = 0.796195
# TKN: Exp ret = -0.081065, Risk = 2.278505
# TMB: Exp ret = 0.097371, Risk = 1.589262
# TOP: Exp ret = 0.144116, Risk = 0.944116
# TPIPL: Exp ret = -0.070096, Risk = 2.410914
# TRUE: Exp ret = 0.136736, Risk = 3.515792
# TTA: Exp ret = -0.045876, Risk = 2.394171
# TTCL: Exp ret = -0.004730, Risk = 3.813633
# TTW: Exp ret = 0.074211, Risk = 0.990977
# TU: Exp ret = 0.018428, Risk = 1.476532
# TVO: Exp ret = -0.148812, Risk = 1.162102
# UNIQ: Exp ret = -0.069069, Risk = 1.958712
# VGI: Exp ret = 0.134575, Risk = 1.942920
# VIBHA: Exp ret = -0.063409, Risk = 1.233050
# VNG: Exp ret = -0.160770, Risk = 1.689794
# WHA: Exp ret = 0.104126, Risk = 2.133289

# %%
# 2 Minimize Variance

# Set up the optimization model
# Number of variables
n = len(symbols)
# The variables vector
x = Variable(n)

# %%
# The return
ret = r.T*x
# The risk in xT.Q.x format
risk = quad_form(x, C)
# Out:
# /opt/conda/lib/python3.7/site-packages/cvxpy/expressions/expression.py:516: UserWarning:
# This use of ``*`` has resulted in matrix multiplication.
# Using ``*`` for matrix multiplication has been deprecated since CVXPY 1.1.
#     Use ``*`` for matrix-scalar and vector-scalar multiplication.
#     Use ``@`` for matrix-matrix and matrix-vector multiplication.
#     Use ``multiply`` for elementwise multiplication.
#
#   warnings.warn(__STAR_MATMUL_WARNING__, UserWarning)

# %%
# The core problem definition with the Problem class from CVXPY
#.  Leave out req_return >= 0

prob = Problem(Minimize(risk), [sum(x)==1, x >= 0])

# %%
# Try solving the problem (within a try/except loop)
try: 
    prob.solve()
    print ("Optimal portfolio") 
    print ("----------------------") 
    for s in range(len(symbols)):
        print (" Investment in {} : {}% of the portfolio".format(symbols[s],round(100*x.value[s],2)))
    print ("----------------------")
    print ("Exp ret = {}%".format(round(100*ret.value,2)))
    print ("Expected risk = {}%".format(round(100*risk.value**0.5,2)))
except:
    print ("Error")
# Out:
# Optimal portfolio
# ----------------------
#  Investment in AAV : 0.31% of the portfolio
#  Investment in ADVANC : 0.0% of the portfolio
#  Investment in AMATA : -0.0% of the portfolio
#  Investment in AOT : 6.68% of the portfolio
#  Investment in AP : 0.49% of the portfolio
#  Investment in BA : 2.69% of the portfolio
#  Investment in BANPU : 0.0% of the portfolio
#  Investment in BBL : 3.91% of the portfolio
#  Investment in BCH : 2.84% of the portfolio
#  Investment in BCP : -0.0% of the portfolio
#  Investment in BDMS : 2.75% of the portfolio
#  Investment in BEAUTY : 2.44% of the portfolio
#  Investment in BEC : -0.0% of the portfolio
#  Investment in BEM : 0.45% of the portfolio
#  Investment in BH : 0.29% of the portfolio
#  Investment in BIG : 5.7% of the portfolio
#  Investment in BLA : 0.0% of the portfolio
#  Investment in BTS : 2.39% of the portfolio
#  Investment in CBG : -0.0% of the portfolio
#  Investment in CENTEL : 0.0% of the portfolio
#  Investment in CHG : -0.0% of the portfolio
#  Investment in CK : -0.0% of the portfolio
#  Investment in CKP : -0.0% of the portfolio
#  Investment in CPALL : 5.3% of the portfolio
#  Investment in CPF : 0.0% of the portfolio
#  Investment in CPN : 2.91% of the portfolio
#  Investment in DELTA : 0.09% of the portfolio
#  Investment in EGCO : 10.79% of the portfolio
#  Investment in EPG : 0.08% of the portfolio
#  Investment in GLOBAL : 0.0% of the portfolio
#  Investment in GUNKUL : -0.0% of the portfolio
#  Investment in HANA : 0.29% of the portfolio
#  Investment in HMPRO : -0.0% of the portfolio
#  Investment in ICHI : -0.0% of the portfolio
#  Investment in INTUCH : -0.0% of the portfolio
#  Investment in IRPC : -0.0% of the portfolio
#  Investment in ITD : -0.0% of the portfolio
#  Investment in IVL : -0.0% of the portfolio
#  Investment in KAMART : 2.08% of the portfolio
#  Investment in KBANK : -0.0% of the portfolio
#  Investment in KCE : 4.9% of the portfolio
#  Investment in KKP : 0.29% of the portfolio
#  Investment in KTB : -0.0% of the portfolio
#  Investment in KTC : 1.51% of the portfolio
#  Investment in LH : 0.0% of the portfolio
#  Investment in LPN : -0.0% of the portfolio
#  Investment in MAJOR : 1.99% of the portfolio
#  Investment in MINT : -0.0% of the portfolio
#  Investment in PLANB : 0.0% of the portfolio
#  Investment in PTG : -0.0% of the portfolio
#  Investment in PTT : 2.17% of the portfolio
#  Investment in PTTEP : -0.0% of the portfolio
#  Investment in PTTGC : 0.62% of the portfolio
#  Investment in S : -0.0% of the portfolio
#  Investment in SAMART : -0.0% of the portfolio
#  Investment in SAWAD : 1.18% of the portfolio
#  Investment in SCB : -0.0% of the portfolio
#  Investment in SCC : 0.22% of the portfolio
#  Investment in SCN : -0.0% of the portfolio
#  Investment in SGP : -0.0% of the portfolio
#  Investment in SIRI : 0.0% of the portfolio
#  Investment in SPALI : 3.07% of the portfolio
#  Investment in SPCG : -0.0% of the portfolio
#  Investment in SPRC : -0.0% of the portfolio
#  Investment in STEC : -0.0% of the portfolio
#  Investment in STPI : -0.0% of the portfolio
#  Investment in SUPER : -0.0% of the portfolio
#  Investment in TASCO : 0.34% of the portfolio
#  Investment in TCAP : -0.0% of the portfolio
#  Investment in THAI : -0.0% of the portfolio
#  Investment in THANI : 1.05% of the portfolio
#  Investment in THCOM : 0.05% of the portfolio
#  Investment in TISCO : 5.01% of the portfolio
#  Investment in TKN : 0.0% of the portfolio
#  Investment in TMB : 1.48% of the portfolio
#  Investment in TOP : 3.95% of the portfolio
#  Investment in TPIPL : 0.0% of the portfolio
#  Investment in TRUE : -0.0% of the portfolio
#  Investment in TTA : -0.0% of the portfolio
#  Investment in TTCL : -0.0% of the portfolio
#  Investment in TTW : 10.51% of the portfolio
#  Investment in TU : 1.7% of the portfolio
#  Investment in TVO : 2.55% of the portfolio
#  Investment in UNIQ : -0.0% of the portfolio
#  Investment in VGI : 0.28% of the portfolio
#  Investment in VIBHA : 2.41% of the portfolio
#  Investment in VNG : 2.21% of the portfolio
#  Investment in WHA : 0.0% of the portfolio
# ----------------------
# Exp ret = 4.33%
# Expected risk = 29.68%

# %%
import pandas as pd 
dat = {}
for s in range(len(symbols)): 
    dat[symbols[s]] = round(100*x.value[s],2)

alloc_weight_period1 = pd.DataFrame.from_dict(dat, orient='index').T

alloc_weight_period1 = alloc_weight_period1.T

alloc_weight_period1
# Out:
#            0
# AAV     0.31
# ADVANC  0.00
# AMATA  -0.00
# AOT     6.68
# AP      0.49
# ...      ...
# UNIQ   -0.00
# VGI     0.28
# VIBHA   2.41
# VNG     2.21
# WHA     0.00
#
# [88 rows x 1 columns]

# %%
alloc_weight_period1.plot(kind='bar', figsize=(20, 12), fontsize=14, legend=False, title="Suggest Allocation from Prediction Data (Minimum-Variance) (Day XXXX-XX-XX)")
