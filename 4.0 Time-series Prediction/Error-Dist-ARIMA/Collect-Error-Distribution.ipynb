# %%
from arima_errors import collect_error_data

collect_error_data()
# Out:
# History: 50 days Forecast: 1 days
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~/4.0 Time-series Prediction/Error-Dist-ARIMA/arima_errors.py in collect_forecast_perf(df, all_obs, ndays, window, arima_order)
#      92         model = ARIMA(history, order=arima_order) # (3,1,0) by default
# ---> 93         model_fit = model.fit(disp=0)
#      94         output = model_fit.forecast(ndays)
#
# /opt/conda/lib/python3.7/site-packages/statsmodels/tsa/arima_model.py in fit(self, start_params, trend, method, transparams, solver, maxiter, full_output, disp, callback, start_ar_lags, **kwargs)
#    1199                                         maxiter, full_output, disp,
# -> 1200                                         callback, start_ar_lags, **kwargs)
#    1201         normalized_cov_params = None  # TODO: fix this?
#
# ...

# %%
# !python arima_errors.py
